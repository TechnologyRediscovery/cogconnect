# %%
import csv
import random
import re
import time
import psycopg2
import itertools
# import csv_utils
import requests
import bs4
from unidecode import unidecode

CSV_FILE_ENCODING = 'utf-8'
# global municodemap
# global current_muni
# global MUNI_PARCELID_LIST_FILE
# global muni_idbase_map
# global ID_BASE
# global TEST_PARID_FILE

def main():
    # for accessing a list of all parcelIDs by with one muni's list per file
    # global INPUT_FILE
    # INPUT_FILE = 'workspace/pitcairnparids.csv'

    # parcels whose base property data is not written are written here before moving on
    global LOG_FILE
    LOG_FILE = 'output/swissvaleerror.csv'

    # this log file is used for storing parcels whose person and propertyperson inserts fail
    global LOG_FILE_AUX
    LOG_FILE_AUX = 'output/swissvaleerror_aux.csv'

    # ID number of the system user connected to these original inserts
    # user 99 is sylvia, our COG robot
    global UPDATING_USER_ID
    UPDATING_USER_ID = 99

    global PARID_FILE
    # PARID_FILE = 'parcelidlists/wilmerdingparids.csv'
    # PARID_FILE = 'parcelidlists/parcelidstest.csv'
    #PARID_FILE = 'parcelidlists/pitcairnparids_correct.csv'
    #PARID_FILE = 'parcelidlists/eastmckeesportparids.csv'
    #PARID_FILE = 'parcelidlists/wilkinsparcelids.csv'
    #PARID_FILE = 'parcelidlists/chalfantparcelids.csv'
    PARID_FILE = 'parcelidlists/swissvaleparcelids.csv'
    
    # used as the access key for muni codes and ID bases in the dictionaries below
    global current_muni
    current_muni = 'swissvale'

    # use as floor value for all new propertyIDs
    global PROP_ID_BASE
    PROP_ID_BASE = 100000

    # floor value for new personIDs
    global PERSON_ID_BASE
    PERSON_ID_BASE = 10000

    # used for sliding starting ID up to accommodate a parcelid list adjustment due to errors on pesky parcels
    # must be manually set if there's an error: start one above the most recently issued ID
    # this gets added to the base ID in the ID range generation methods
    global BUMP_UP
    BUMP_UP = 0

    global municodemap
    municodemap = {'chalfant':814,'churchhill':816, 'eastmckeesport':821, 'pitcairn':847, 'wilmerding':867, 'wilkins':953, 'cogland':999, 'swissvale':111}

    # add these base amounts to the universal base to get starting IDs
    global muni_idbase_map
    muni_idbase_map = {'chalfant':10000,'churchhill':20000, 'eastmckeesport':30000, 'pitcairn':40000, 'wilmerding':0, 'wilkins':50000, 'cogland':60000, 'swissvale':70000}

    # add these base amounts to the universal base to get starting IDs
    global person_idbase_map
    person_idbase_map = {'chalfant':10000,'churchhill':20000, 'eastmckeesport':30000, 'pitcairn':40000, 'wilmerding':0, 'wilkins':50000, 'cogland':60000, 'swissvale':70000}

    # jump into the actual work here
    insert_property_basetableinfo()
    
    # Add owner data to properties
    # properties_with_owner_info = add_prop_info(properties)
    # Save new CSV file with property plus owner data
    # OUTPUT_FILE = 'output/testPropOut.txt'
    # save_properties_as_csv(properties_with_owner_info, OUTPUT_FILE)

def get_nextpropertyid(munioffset):
    # consider a range multiplier by municipality to generate starting 
    # at, say 110000 and the next at 120000 which allows for non-overlapping
    #ids for munis with a property count of up to 10000
    for i in list(range(PROP_ID_BASE + munioffset + BUMP_UP, PROP_ID_BASE + munioffset + 9999)):
        yield i;

def get_nextpersonid(munioffset):
    for i in list(range(PERSON_ID_BASE + munioffset + BUMP_UP, PERSON_ID_BASE + munioffset + 9999)):
        yield i;



def get_nextparcelid(input_file):
    # Read the CSV file and iterate through every property
    with open(input_file, 'r', encoding=CSV_FILE_ENCODING) as csv_file:
        reader = csv.DictReader(csv_file)
        for row in reader:
            parid = str(row['parcelid']).strip()
            yield parid


def logerror(parcelid):
    with open(LOG_FILE, 'a', encoding=CSV_FILE_ENCODING) as outfile:
        writer = csv.writer(outfile)
        writer.writerow([parcelid])

def logerror_aux(parcelid):
    with open(LOG_FILE_AUX, 'a', encoding=CSV_FILE_ENCODING) as outfile:
        writer = csv.writer(outfile)
        writer.writerow([parcelid])

# for debugging and transferability purposes
def save_properties_as_csv(properties_with_owner_info, output_file):
    fieldnames = None
    with open(output_file, 'w', encoding=CSV_FILE_ENCODING) as outfile:
        writer = csv.writer(outfile)
        for prop in properties_with_owner_info:
            if fieldnames is None:
                fieldnames = sorted(prop.keys())
                writer.writerow(fieldnames)
            writer.writerow([prop[k] for k in fieldnames])

            
def connect_person_to_property(propertyid, personid):
    db_conn = get_db_conn()
    cursor = db_conn.cursor()

    insert_sql = """
        INSERT INTO public.propertyperson(
            property_propertyid, person_personid)
    VALUES (%(prop)s, %(pers)s);
    """
    insertmap = {}
    
    # load up vars for use in SQL from each of the parse methods
    insertmap['prop'] = propertyid
    insertmap['pers'] = personid

    cursor.execute(insert_sql, insertmap)
    db_conn.commit()
    print('----- connected person owner to property -----')

def create_and_insert_unitzero(propertyid):
    db_conn = get_db_conn()
    cursor = db_conn.cursor()
    
    insert_sql = """
        INSERT INTO public.propertyunit(
            unitid, unitnumber, property_propertyid, otherknownaddress, notes, 
            rental)
        VALUES (DEFAULT, '0', %(property_propertyid)s, NULL, 
            'robot-generated unit representing the primary habitable dwelling on a property', 
            FALSE);
    """
    insertmap = {}
    
    # load up vars for use in SQL from each of the parse methods
    insertmap['property_propertyid'] = propertyid

    cursor.execute(insert_sql, insertmap)
    db_conn.commit()
    print('----- built unit zero -----')


# deprecated from Daniel--kept in as a reference
def add_prop_info(properties):
    PARCEL_ID_FIELD = 'parcelid'
    OWNER_NAME_FIELD = 'OwnerName'
    OWNER_ADDRESS_FIELD = 'OwnerAddress'
    for prop in properties:
        assert prop[PARCEL_ID_FIELD]  # Every property must have a parcel id
        parcel_id = prop[PARCEL_ID_FIELD]
        print('Processing parcel', parcel_id)

        # Get the html from the county's website
        property_html = get_county_page_for(parcel_id)

        # Wait between request, just to be nice with the county's site
        sleep_time = random.random() * 3  # Sleep at most 3 seconds
        time.sleep(sleep_time)
        print('sleeping for {:.2f} seconds'.format(sleep_time))

        # Add owner name and address to the property
        prop[OWNER_NAME_FIELD] = extract_owner_name(parcel_id, property_html)
        prop[OWNER_ADDRESS_FIELD] = extract_owner_address(
                parcel_id, property_html)
        print(prop[OWNER_NAME_FIELD], prop[OWNER_ADDRESS_FIELD])

        yield prop


county_info_cache = {}
def get_county_page_for(parcel_id):
    if parcel_id in county_info_cache:
        return county_info_cache[parcel_id]
    COUNTY_REAL_ESTATE_URL = ('http://www2.county.allegheny.pa.us/'
                              'RealEstate/GeneralInfo.aspx?')
    search_parameters = {
        'ParcelID': parcel_id,
        'SearchType': 3,
        'SearchParcel': parcel_id}
    waittime = random.uniform(0.0,1.0)
    print("waiting:" + str(waittime))
    time.sleep(waittime)
    try:
        response = requests.get(
                COUNTY_REAL_ESTATE_URL,
                params=search_parameters,
                timeout=5)
        print('Scraping data from county: %s' + parcel_id)
    except requests.exceptions.Timeout:
        # Wait 10 secs and try one more time
        time.sleep(10)
        response = requests.get(
                COUNTY_REAL_ESTATE_URL,
                params=search_parameters,
                timeout=5)
    county_info_cache[parcel_id] = response.text
    return response.text

#---------------------------------------------
#           HTML SCRAPING METHODS
#---------------------------------------------

def extract_lotandblock_fromparid(parid):
    trimmedparid = parid[0:11]
    exp = re.compile(r'([1-9]+)(\w)[0]*([1-9]+)')
    gl = re.search(exp, trimmedparid)
    if(gl):
        lob = gl.group(1) + '-' + gl.group(2) + '-' + gl.group(3)
        return lob
    else:
        print('ERROR: LOB parsing')
        return ''

def extract_owner_name(property_html):
    OWNER_NAME_SPAN_ID = 'BasicInfo1_lblOwner'
    persondict = {}

    soup = bs4.BeautifulSoup(property_html, 'lxml')
    owner_full_name = soup.find('span', id=OWNER_NAME_SPAN_ID).text
    print('owner_raw_name:' + str(owner_full_name))
    # Remove extra spaces from owner's name
    full_owners = re.sub(r'\s+', ' ', owner_full_name.strip())
    
    #exp = re.compile(r'(\w+|[&])\s+(\w+|[&])\s*(\w*|[&]).*')
    #namegroups = re.search(exp, owner_full_name)
    #print(len(namegroups.groups()))
    #persondict['lname'] = str(namegroups.group(1)).title()
    
    #if len(namegroups.groups()) == 2:
        #persondict['fname'] = str(namegroups.group(2)).title()
    #elif len(namegroups.groups()) == 3:
        #persondict['fname'] = str(namegroups.group(2)).title() + ' ' + str(namegroups.group(3)).title()

    #print(str(persondict['fname']) + ' ' + str(persondict['lname']))
    
    return full_owners

def extract_propertyaddress(parcel_id, property_html):
    propaddrmap = {}
    PROP_ADDR_SPAN_ID = 'BasicInfo1_lblAddress'
    # print(property_html)
    soup = bs4.BeautifulSoup(property_html, 'lxml')
    
    # this yeilds something like
    # 471&nbsp;WALNUT  ST<br>PITTSBURGH,&nbsp;PA&nbsp;15238
    prop_addr_raw = soup.find('span', id=PROP_ADDR_SPAN_ID).text
    scrapedhtml = soup.select("#BasicInfo1_lblAddress")

    print("Scraped:" + str(scrapedhtml))
    soup = bs4.BeautifulSoup(str(scrapedhtml), 'lxml')
    adrlistraw = soup.span.contents 
    # make sure we have all the parts of the address
    if len(adrlistraw) < 3:
        print("Raising Exception in extract_propertyaddress")
        raise Exception
    
    street = re.sub('  ', ' ', adrlistraw[0])
    propaddrmap['street'] = str(unidecode(street)).strip()
    print(propaddrmap['street'])
    # on the city, state, zip line, grab until the comma before the state
    exp = re.compile('[^,]*')
    propaddrmap['city'] = exp.search(adrlistraw[2]).group()
    print("city:" + propaddrmap['city'])
    # hard-code pa
    propaddrmap['state']= 'PA'
    # zip is just the last 5 chars    
    propaddrmap['zipc'] = adrlistraw[2][-5:]
    print("Zip:" + propaddrmap['zipc'])

    return propaddrmap

def extract_owneraddress(property_html):
    print('--------- extracting owner address ------------')
    owneraddrmap = {}
    # print(property_html)
    soup = bs4.BeautifulSoup(property_html, 'lxml')
    # this yeilds something like
    # 471&nbsp;WALNUT  ST<br>PITTSBURGH,&nbsp;PA&nbsp;15238
    scrapedhtml = soup.select("#lblChangeMail")
    owneraddrmap['notes_adrdump'] = str(scrapedhtml)

    print("Scraped:" + str(scrapedhtml))
    soup = bs4.BeautifulSoup(str(scrapedhtml), 'lxml')
    # this spits out a three-item list. We throw away the <br> which is 
    # the middle item. The first is the street, the second gets chopped up
    adrlistraw = soup.span.contents 
    # make sure we have all the parts of the address
    if len(adrlistraw) < 3:
        print("Raising Exception")
        raise Exception
    
    addrlistindex = 0
    if len(adrlistraw) > 3:
        print("Extra line address")
        addrlistindex += 2
        
    ownerstreet = re.sub('  ', ' ', adrlistraw[addrlistindex])
    owneraddrmap['street'] = str(unidecode(ownerstreet)).strip()
    print(owneraddrmap['street'])
    # on the city, state, zip line, grab until the comma before the state
    exp = re.compile('[^,]*')
    addrlistindex += 2
    owneraddrmap['city'] = exp.search(adrlistraw[addrlistindex]).group()
    print("city:" + owneraddrmap['city'])
    # grap with string indexes (fragile if there is more than one space before zip)
    # TODO: use regexp
    exp=re.compile(r',\s*(\w\w)')
    m = re.search(exp,adrlistraw[addrlistindex])
    owneraddrmap['state'] = str(m.group(1))
    
    # abandoned string slicing approach (too brittle; use regexp)
    # owneraddrmap['state']= adrlistraw[2][-13:-11]
    print("state:" + owneraddrmap['state'])
    
    # owner zips could come in as: 15218 OR 15218- OR 15218-2342
    # just lose the routing numbers and take the first digits until the -
    exp=re.compile(r'\d+')
    m = re.search(exp, adrlistraw[addrlistindex])
    owneraddrmap['zipc'] = str(m.group())

    # another abandoned string slicing approach: 
    # also too brittle given range of scraped inputs
    # owneraddrmap['zip'] = adrlistraw[2][-10:]
    print("zip:" + owneraddrmap['zipc'])

    return owneraddrmap


def extact_owner_name_and_mailing(parcel_id, property_html):

    OWNER_ADDRESS_SPAN_ID = 'lblChangeMail'
    addrparts = {}

    soup = bs4.BeautifulSoup(property_html, 'lxml')
    owner_address_raw = soup.find('span', id=OWNER_ADDRESS_SPAN_ID).text
    # Remove extra spaces
    addrparts['addr'] = rs.sub('')

    owner_address = re.sub(r'\s+', ' ', owner_address.strip())
    # Remove leading spaces before commas
    owner_address = re.sub(r'\s+,', ',', owner_address)

    return owner_address


def extract_propertyusetype(property_html):
    USE_TYPE_SPAN_ID = 'lblUse'

    soup = bs4.BeautifulSoup(property_html, 'lxml')
    usetype = soup.find('span', id=USE_TYPE_SPAN_ID).text
    # Remove extra spaces
    usetype = re.sub(r'\s+', ' ', usetype.strip())
    # Remove leading spaces before commas
    usetype = str(re.sub(r'\s+,', ',', usetype)).title()
    return usetype

def extract_class(property_html):
    CLASS_SPAN_ID = 'lblState'

    soup = bs4.BeautifulSoup(property_html, 'lxml')
    propclass = soup.find('span', id=CLASS_SPAN_ID).text
    # Remove extra spaces
    propclass = re.sub(r'\s+', ' ', propclass.strip())
    # Remove leading spaces before commas
    propclass = str(re.sub(r'\s+,', ',', propclass)).title()
    return propclass

def extract_ownercode(property_html):
    OWNER_CODE_SPAN_ID = 'lblOwnerCode'

    soup = bs4.BeautifulSoup(property_html, 'lxml')
    ownercode = soup.find('span', id=OWNER_CODE_SPAN_ID).text
    # Remove extra spaces
    ownercode = re.sub(r'\s+', ' ', ownercode.strip())
    # Remove leading spaces before commas
    ownercode = str(re.sub(r'\s+,', ',', ownercode)).title()
    return ownercode

def check_current_owner(parcelid):
    namemap = {}
    get_propid = "SELECT propertyid FROM public.property WHERE parid=%(parcelid)s;"
    inserts = {}
    inserts['parcelid'] = parcelid
    db_conn = get_db_conn()
    cursor = db_conn.cursor()
    cursor.execute(get_propid, inserts)
    propidlist = cursor.fetchall()
    propid = propidlist[0][0]
    get_personid = "SELECT person_personid FROM public.propertyperson WHERE property_propertyid=%(property_propertyid)s;"
    inserts['property_propertyid'] = propid
    cursor.execute(get_personid, inserts)
    personidlist = cursor.fetchall()
    personid = personidlist[0][0]
    get_names = "SELECT fname, lname FROM public.person WHERE personid=%(personid)s"
    inserts['personid'] = personid
    cursor.execute(get_names, inserts)
    names = cursor.fetchall()
    print(names)
    namemap['fname'] = names[0][0]
    namemap['lname'] = names[0][1]
    return namemap

def extract_and_insert_person(rawhtml, propertyid, personid, propinserts):
    # fixed values specific to keys in lookup tables
    

    db_conn = get_db_conn()
    cursor = db_conn.cursor()

    notemsg = """In case of confusion, check autmated record entry with raw text from the county database:"""

    insert_sql = """
        INSERT INTO public.person(
            personid, persontype, muni_municode, fname, lname, jobtitle, 
            phonecell, phonehome, phonework, email, address_street, address_city, 
            address_state, address_zip, notes, lastupdated, expirydate, isactive, 
            isunder18, humanverifiedby,compositelname, mailing_address_street, mailing_address_city,
            mailing_address_state, mailing_address_zip, useseparatemailingaddr)
    VALUES (%(personid)s, cast ( 'ownercntylookup' as persontype), 
            %(muni_municode)s, NULL, %(lname)s, 'Property Owner', 
            NULL, NULL, NULL, NULL, %(address_street)s, %(address_city)s, 
            %(address_state)s, %(address_zip)s, %(notes)s, now(), NULL, TRUE, 
            FALSE, NULL, true, %(mailing_street)s, %(mailing_city)s, %(mailing_state)s, %(mailing_zip)s,
            %(mailingsameasres)s);
    """
    
    
    """INSERT INTO public.person(
	personid, persontype, muni_municode, fname, lname, jobtitle, phonecell, phonehome, phonework, 
    email, address_street, address_city, address_state, address_zip, notes, lastupdated, expirydate, 
    isactive, isunder18, humanverifiedby, compositelname, sourceid, creator, businessentity, 
    mailing_address_street, mailing_address_city, mailing_address_zip, mailing_address_state, 
    useseparatemailingaddr, expirynotes, creationtimestamp, canexpire, userlink)
	VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""
    
    insertmap = {}
    
    # load up vars for use in SQL from each of the parse methods
    insertmap['personid'] = personid
    print("personid:"+str(insertmap['personid']))
    insertmap['muni_municode'] = str(municodemap[current_muni])
    
    insertmap['mailing_street'] = None
    insertmap['mailing_city'] = None
    insertmap['mailing_state'] = None
    insertmap['mailing_zip'] = None
    insertmap['mailingsameasres'] = 'true'
    
    try:
        ownername = extract_owner_name(rawhtml)
        insertmap['lname'] = ownername
        print('extracted owner:' + insertmap['lname'] )

    except Exception:
        print("Malformed owner name at e and i person")
        print("ERROR malformed address at:" + str(propertyid))
    
    try:
        owneraddrmap = extract_owneraddress(rawhtml)
        print("ARE THEY THE SAME??? " + str(owneraddrmap['street'] == propinserts['street']))
        print(propinserts)
        if owneraddrmap['street'] == propinserts['street']:
            print("SAME ADDRESS")
            insertmap['address_street'] = owneraddrmap['street']
            insertmap['address_city'] = owneraddrmap['city']
            insertmap['address_state'] = owneraddrmap['state']
            insertmap['address_zip'] = owneraddrmap['zipc']
        else:
            print("DIFFERENT MAILING")
            insertmap['address_street'] = None
            insertmap['address_city'] = None
            insertmap['address_state'] = None
            insertmap['address_zip'] = None
            insertmap['mailing_street'] = owneraddrmap['street']
            insertmap['mailing_city'] = owneraddrmap['city']
            insertmap['mailing_state'] = owneraddrmap['state']
            insertmap['mailing_zip'] = owneraddrmap['zipc']
            insertmap['mailingsameasres'] = 'false'
        insertmap['notes'] = notemsg + ownername + " Raw address: " + owneraddrmap['notes_adrdump']

    except Exception:
        print("NO MAILING")
        insertmap['address_street'] = propinserts['street']
        insertmap['address_city'] = propinserts['city']
        insertmap['address_state'] = propinserts['state']
        insertmap['address_zip'] = propinserts['zipc']
        insertmap['notes'] = "Owner does not have mailing address"

        
    print(insertmap['mailing_zip'])
    if insertmap['address_street']:
        print('extracted owner address:' \
            + ' ' + insertmap['address_street'] \
            + ' ' + insertmap['address_city'] \
            + ', ' + insertmap['address_state'] \
            + ' ' + insertmap['address_zip'])
    if insertmap['mailing_street']:
        print('extracted mailing address:' \
            + ' ' + insertmap['mailing_street'] \
            + ' ' + insertmap['mailing_city'] \
            + ', ' + insertmap['mailing_state'] \
            + ' ' + insertmap['mailing_zip'])

    
    print('Inserting person data for id: %s' % (insertmap['personid']))
    print('person notes:' + insertmap['notes'])
    
    cursor.execute(insert_sql, insertmap)
    db_conn.commit()
    print('----- committed person owner -----')
    # commit core propertytable insert
def insert_property_basetableinfo():
    db_conn = get_db_conn()
    cursor = db_conn.cursor()
    parcelgenerator = get_nextparcelid(PARID_FILE)
    propertyidgenerator = get_nextpropertyid(muni_idbase_map[current_muni])
    personidgenerator = get_nextpersonid(person_idbase_map[current_muni])

    # user 99 is the cog robot, Sylvia
    insert_sql = """
        INSERT INTO public.property(
            propertyid, municipality_municode, parid, address, 
            notes, addr_city, addr_state, addr_zip,
            lotandblock, propclass, propertyusetype, ownercode,
            lastupdated, lastupdatedby)
        VALUES (%(propid)s, %(muni)s, %(parcelid)s, %(addr)s, 
                %(notes)s, %(city)s, %(state)s, %(zipcode)s,
                %(lotandblock)s, %(propclass)s, %(propertyusetype)s, %(ownercode)s,
                now(), %(updatinguser)s);

    """
    insertmap = {}
    propertycount = 0
    personcount = 0
    # the main delegator loop
    for parid in parcelgenerator:
        # go get raw HTML
        rawhtml = get_county_page_for(parid)
        
        # load up vars for use in SQL from each of the parse methods
        insertmap['propid'] = next(propertyidgenerator)
        propid = insertmap['propid']
        print("newid:"+ str(propid))
        # parid comes from the iterated item variable parid
        insertmap['parcelid'] = parid
        insertmap['muni'] = municodemap[current_muni]
        try:
            addrmap = extract_propertyaddress(parid, rawhtml)
        except Exception:
            print("MA base table")
            print("ERR malformed address at:" + parid)
            logerror(parid)
            continue
        insertmap['addr'] = addrmap['street']
        insertmap['notes'] = 'core data scraped from county site'
        insertmap['city'] = addrmap['city']
        insertmap['state'] = addrmap['state']
        insertmap['zipcode'] = addrmap['zipc']   
        insertmap['lotandblock'] = extract_lotandblock_fromparid(parid)
        # print('lob:' + insertmap['lotandblock'])

        insertmap['propclass'] = str(extract_class(rawhtml))
        # print('class:' + insertmap['propclass'])

        insertmap['propertyusetype'] = extract_propertyusetype(rawhtml)
        # print('use:' + insertmap['propertyusetype'])

        insertmap['ownercode'] = extract_ownercode(rawhtml)
        # print('owner code:' + insertmap['ownercode'])

        insertmap['updatinguser'] = str(99)
        # print('updater id:' + insertmap['updatinguser'])

        print('Inserting parcelid data: %s' % (parid))
        
        try:
            # execute insert on property table
            cursor.execute(insert_sql, insertmap)
            # commit core propertytable insert
            db_conn.commit()
            propertycount = propertycount + 1
            print('----- committed property core table -----')
        except:
            print('ERROR: unable to insert base property data...skipping\n')
            print('********* MOVING ON ********************')
            logerror_aux(parid)
            continue
        try:
        # this try catches soup related errors
        # and sql errors bubbling up from the extraction methods that also commit
            personid = next(personidgenerator)
            print(1)
            extract_and_insert_person(rawhtml, propid, personid, addrmap)
            print(2)
            connect_person_to_property(propid, personid)
            print(3)
            personcount = personcount + 1
        except:
            print('ERROR: unable to extract, commit, or connect person owner\n')
            logerror_aux(parid)
            continue
        try:
            # create standard unit number 0 for each property in system
            create_and_insert_unitzero(propid)
        except:
            print('ERROR: unable to create unit zero for property no.\n'+ str(propid))
            logerror(parid)
            continue
        print('--------- running totals --------')
        print('Props inserted: ' + str(propertycount))
        print('Persons inserted: ' + str(personcount))
        print('********** DONE! *************\n')

        # run insert with sql statement all loaded up
    cursor.close()
    db_conn.close()
    print('Count of properties inserted: ' + str(propertycount))
    print('Count of persons inserted: ' + str(personcount))

# db debugging--don't forget conn.commit!
    # newid = insertmap['id']
    #     selectsql = """
    #         SELECT * from property;
    #     """
    #     cursor.execute(selectsql)
    #     print(cursor.fetchone())


if __name__ == '__main__':
    main()

# %%
import csv
import random
import re
import time
import psycopg2
import itertools
# import csv_utils
import requests
import bs4
from unidecode import unidecode

CSV_FILE_ENCODING = 'utf-8'
# global municodemap
# global current_muni
# global MUNI_PARCELID_LIST_FILE
# global muni_idbase_map
# global ID_BASE
# global TEST_PARID_FILE

def main():
    # for accessing a list of all parcelIDs by with one muni's list per file
    # global INPUT_FILE
    # INPUT_FILE = 'workspace/pitcairnparids.csv'

    # parcels whose base property data is not written are written here before moving on
    global LOG_FILE
    LOG_FILE = 'output/swissvaleerror.csv'

    # this log file is used for storing parcels whose person and propertyperson inserts fail
    global LOG_FILE_AUX
    LOG_FILE_AUX = 'output/swissvaleerror_aux.csv'

    # ID number of the system user connected to these original inserts
    # user 99 is sylvia, our COG robot
    global UPDATING_USER_ID
    UPDATING_USER_ID = 99

    global PARID_FILE
    # PARID_FILE = 'parcelidlists/wilmerdingparids.csv'
    # PARID_FILE = 'parcelidlists/parcelidstest.csv'
    #PARID_FILE = 'parcelidlists/pitcairnparids_correct.csv'
    #PARID_FILE = 'parcelidlists/eastmckeesportparids.csv'
    #PARID_FILE = 'parcelidlists/wilkinsparcelids.csv'
    #PARID_FILE = 'parcelidlists/chalfantparcelids.csv'
    PARID_FILE = 'parcelidlists/swissvaleparcelids.csv'
    
    # used as the access key for muni codes and ID bases in the dictionaries below
    global current_muni
    current_muni = 'swissvale'

    # use as floor value for all new propertyIDs
    global PROP_ID_BASE
    PROP_ID_BASE = 100000

    # floor value for new personIDs
    global PERSON_ID_BASE
    PERSON_ID_BASE = 10000

    # used for sliding starting ID up to accommodate a parcelid list adjustment due to errors on pesky parcels
    # must be manually set if there's an error: start one above the most recently issued ID
    # this gets added to the base ID in the ID range generation methods
    global BUMP_UP
    BUMP_UP = 0

    global municodemap
    municodemap = {'chalfant':814,'churchhill':816, 'eastmckeesport':821, 'pitcairn':847, 'wilmerding':867, 'wilkins':953, 'cogland':999, 'swissvale':111}

    # add these base amounts to the universal base to get starting IDs
    global muni_idbase_map
    muni_idbase_map = {'chalfant':10000,'churchhill':20000, 'eastmckeesport':30000, 'pitcairn':40000, 'wilmerding':0, 'wilkins':50000, 'cogland':60000, 'swissvale':70000}

    # add these base amounts to the universal base to get starting IDs
    global person_idbase_map
    person_idbase_map = {'chalfant':10000,'churchhill':20000, 'eastmckeesport':30000, 'pitcairn':40000, 'wilmerding':0, 'wilkins':50000, 'cogland':60000, 'swissvale':70000}

    # jump into the actual work here
    #insert_property_basetableinfo()
    
    # Add owner data to properties
    # properties_with_owner_info = add_prop_info(properties)
    # Save new CSV file with property plus owner data
    # OUTPUT_FILE = 'output/testPropOut.txt'
    # save_properties_as_csv(properties_with_owner_info, OUTPUT_FILE)

    
if __name__ == '__main__':
    main()
    
def get_nextpersonid(munioffset):
    for i in list(range(PERSON_ID_BASE + munioffset + BUMP_UP, PERSON_ID_BASE + munioffset + 9999)):
        yield i;

        
db_conn = None
def get_db_conn():
    global db_conn
    if db_conn is not None:
        return db_conn
    db_conn = psycopg2.connect(
        dbname="cogdb",
        user="matts207",
        password="12345",
        host="localhost"
    )
    return db_conn

county_info_cache = {}
def get_county_page_for(parcel_id):
    if parcel_id in county_info_cache:
        return county_info_cache[parcel_id]
    COUNTY_REAL_ESTATE_URL = ('http://www2.county.allegheny.pa.us/'
                              'RealEstate/GeneralInfo.aspx?')
    search_parameters = {
        'ParcelID': parcel_id,
        'SearchType': 3,
        'SearchParcel': parcel_id}
    waittime = random.uniform(0.0,1.0)
    print("waiting:" + str(waittime))
    time.sleep(waittime)
    try:
        response = requests.get(
                COUNTY_REAL_ESTATE_URL,
                params=search_parameters,
                timeout=5)
        print('Scraping data from county: %s' + parcel_id)
    except requests.exceptions.Timeout:
        # Wait 10 secs and try one more time
        time.sleep(10)
        response = requests.get(
                COUNTY_REAL_ESTATE_URL,
                params=search_parameters,
                timeout=5)
    county_info_cache[parcel_id] = response.text
    return response.text

def extract_owneraddress(property_html):
    print('--------- extracting owner address ------------')
    owneraddrmap = {}
    # print(property_html)
    soup = bs4.BeautifulSoup(property_html, 'lxml')
    # this yeilds something like
    # 471&nbsp;WALNUT  ST<br>PITTSBURGH,&nbsp;PA&nbsp;15238
    scrapedhtml = soup.select("#lblChangeMail")
    owneraddrmap['notes_adrdump'] = str(scrapedhtml)

    print("Scraped:" + str(scrapedhtml))
    soup = bs4.BeautifulSoup(str(scrapedhtml), 'lxml')
    # this spits out a three-item list. We throw away the <br> which is 
    # the middle item. The first is the street, the second gets chopped up
    adrlistraw = soup.span.contents 
    # make sure we have all the parts of the address
    if len(adrlistraw) < 3:
        print("Raising Exception")
        raise Exception
    
    addrlistindex = 0
    if len(adrlistraw) > 3:
        print("Extra line address")
        addrlistindex += 2
        
    ownerstreet = re.sub('  ', ' ', adrlistraw[addrlistindex])
    owneraddrmap['street'] = str(unidecode(ownerstreet)).strip()
    print(owneraddrmap['street'])
    # on the city, state, zip line, grab until the comma before the state
    exp = re.compile('[^,]*')
    addrlistindex += 2
    owneraddrmap['city'] = exp.search(adrlistraw[addrlistindex]).group()
    print("city:" + owneraddrmap['city'])
    # grap with string indexes (fragile if there is more than one space before zip)
    # TODO: use regexp
    exp=re.compile(r',\s*(\w\w)')
    m = re.search(exp,adrlistraw[addrlistindex])
    owneraddrmap['state'] = str(m.group(1))
    
    # abandoned string slicing approach (too brittle; use regexp)
    # owneraddrmap['state']= adrlistraw[2][-13:-11]
    print("state:" + owneraddrmap['state'])
    
    # owner zips could come in as: 15218 OR 15218- OR 15218-2342
    # just lose the routing numbers and take the first digits until the -
    exp=re.compile(r'\d+')
    m = re.search(exp, adrlistraw[addrlistindex])
    owneraddrmap['zipc'] = str(m.group())

    # another abandoned string slicing approach: 
    # also too brittle given range of scraped inputs
    # owneraddrmap['zip'] = adrlistraw[2][-10:]
    print("zip:" + owneraddrmap['zipc'])

    return owneraddrmap


def connect_person_to_property(propertyid, personid):
    db_conn = get_db_conn()
    cursor = db_conn.cursor()

    insert_sql = """
        INSERT INTO public.propertyperson(
            property_propertyid, person_personid)
    VALUES (%(prop)s, %(pers)s);
    """
    insertmap = {}
    
    # load up vars for use in SQL from each of the parse methods
    insertmap['prop'] = propertyid
    insertmap['pers'] = personid

    cursor.execute(insert_sql, insertmap)
    db_conn.commit()
    print('----- connected person owner to property -----')
    

def extract_owner_name(property_html):
    OWNER_NAME_SPAN_ID = 'BasicInfo1_lblOwner'
    persondict = {}

    soup = bs4.BeautifulSoup(property_html, 'lxml')
    owner_full_name = soup.find('span', id=OWNER_NAME_SPAN_ID).text
    print('owner_raw_name:' + str(owner_full_name))
    # Remove extra spaces from owner's name
    full_owners = re.sub(r'\s+', ' ', owner_full_name.strip())
    return full_owners


def extract_and_insert_person(rawhtml, ownername, personid, propinserts):
    # fixed values specific to keys in lookup tables
    

    db_conn = get_db_conn()
    cursor = db_conn.cursor()

    notemsg = """In case of confusion, check autmated record entry with raw text from the county database:"""

    insert_sql = """
        INSERT INTO public.person(
            personid, persontype, muni_municode, fname, lname, jobtitle, 
            phonecell, phonehome, phonework, email, address_street, address_city, 
            address_state, address_zip, notes, lastupdated, expirydate, isactive, 
            isunder18, humanverifiedby,compositelname, mailing_address_street, mailing_address_city,
            mailing_address_state, mailing_address_zip, useseparatemailingaddr)
    VALUES (%(personid)s, cast ( 'ownercntylookup' as persontype), 
            %(muni_municode)s, NULL, %(lname)s, 'Property Owner', 
            NULL, NULL, NULL, NULL, %(address_street)s, %(address_city)s, 
            %(address_state)s, %(address_zip)s, %(notes)s, now(), NULL, TRUE, 
            FALSE, NULL, true, %(mailing_street)s, %(mailing_city)s, %(mailing_state)s, %(mailing_zip)s,
            %(mailingsameasres)s);
    """
    
    
    """INSERT INTO public.person(
	personid, persontype, muni_municode, fname, lname, jobtitle, phonecell, phonehome, phonework, 
    email, address_street, address_city, address_state, address_zip, notes, lastupdated, expirydate, 
    isactive, isunder18, humanverifiedby, compositelname, sourceid, creator, businessentity, 
    mailing_address_street, mailing_address_city, mailing_address_zip, mailing_address_state, 
    useseparatemailingaddr, expirynotes, creationtimestamp, canexpire, userlink)
	VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""
    
    insertmap = {}
    
    # load up vars for use in SQL from each of the parse methods
    insertmap['personid'] = personid
    print("personid:"+str(insertmap['personid']))
    insertmap['muni_municode'] = str(municodemap[current_muni])
    
    insertmap['mailing_street'] = None
    insertmap['mailing_city'] = None
    insertmap['mailing_state'] = None
    insertmap['mailing_zip'] = None
    insertmap['mailingsameasres'] = 'true'
    insertmap['lname'] = ownername
    
    try:
        owneraddrmap = extract_owneraddress(rawhtml)
        print("ARE THEY THE SAME??? " + str(owneraddrmap['street'] == propinserts['street']))
        print(propinserts)
        if owneraddrmap['street'] == propinserts['street']:
            print("SAME ADDRESS")
            insertmap['address_street'] = owneraddrmap['street']
            insertmap['address_city'] = owneraddrmap['city']
            insertmap['address_state'] = owneraddrmap['state']
            insertmap['address_zip'] = owneraddrmap['zipc']
        else:
            print("DIFFERENT MAILING")
            insertmap['address_street'] = None
            insertmap['address_city'] = None
            insertmap['address_state'] = None
            insertmap['address_zip'] = None
            insertmap['mailing_street'] = owneraddrmap['street']
            insertmap['mailing_city'] = owneraddrmap['city']
            insertmap['mailing_state'] = owneraddrmap['state']
            insertmap['mailing_zip'] = owneraddrmap['zipc']
            insertmap['mailingsameasres'] = 'false'
        insertmap['notes'] = notemsg + ownername + " Raw address: " + owneraddrmap['notes_adrdump']

    except Exception:
        print("NO MAILING")
        insertmap['address_street'] = propinserts['street']
        insertmap['address_city'] = propinserts['city']
        insertmap['address_state'] = propinserts['state']
        insertmap['address_zip'] = propinserts['zipc']
        insertmap['notes'] = "Owner does not have mailing address"

        
    print(insertmap['mailing_zip'])
    if insertmap['address_street']:
        print('extracted owner address:' \
            + ' ' + insertmap['address_street'] \
            + ' ' + insertmap['address_city'] \
            + ', ' + insertmap['address_state'] \
            + ' ' + insertmap['address_zip'])
    if insertmap['mailing_street']:
        print('extracted mailing address:' \
            + ' ' + insertmap['mailing_street'] \
            + ' ' + insertmap['mailing_city'] \
            + ', ' + insertmap['mailing_state'] \
            + ' ' + insertmap['mailing_zip'])

    
    print('Inserting person data for id: %s' % (insertmap['personid']))
    print('person notes:' + insertmap['notes'])
    
    cursor.execute(insert_sql, insertmap)
    db_conn.commit()
    print('----- committed person owner -----')
    # commit core propertytable insert
    
    

def check_current_owner(parcelid):
    namemap = {}
    db_conn = get_db_conn()
    cursor = db_conn.cursor()
    get_names = """SELECT person.lname, person.personid FROM ((public.person INNER JOIN public.propertyperson
    ON person.personid=propertyperson.person_personid) INNER JOIN public.property 
    ON property.propertyid=propertyperson.property_propertyid) WHERE property.parid=%s AND person.isactive=true;"""
    cursor.execute(get_names, (parcelid, ))
    names = cursor.fetchall()
    print(names)
    namemap = {}
    namemap['lname'] = names[0][0]
    namemap['personid'] = names[0][1]
    print(namemap)
    return namemap

def update_isactive(personid):
    update_sql = """
    UPDATE public.person
    SET isactive = false 
    WHERE personid = %s"""
    
    db = get_db_conn()
    cursor = db.cursor()
    cursor.execute(update_sql, (personid, ))
    cursor.close()
    print("----Old person set to inactive----")

db = get_db_conn()
municode = str(municodemap[current_muni])

props = "SELECT propertyid, parid, address, addr_city, addr_state, addr_zip FROM public.property ORDER BY propertyid;"
propperson = "SELECT person_personid FROM public.propertyperson WHERE property_propertyid = %s;"
personSQL = "SELECT lname FROM public.person WHERE "
highest_person_idSQL = "SELECT MAX(personid) FROM public.person WHERE muni_municode = %s;"
cursor = db.cursor()
cursor.execute(props)
propidlist = cursor.fetchall()
cursor.close()

cursor = db.cursor()
print(municode)
cursor.execute(highest_person_idSQL, (municode,))
firstavailablepersonid = cursor.fetchall()[0][0] + 1
print(firstavailablepersonid)
cursor.close()

for p in propidlist:
    propinserts = {}
    propinserts['street'] = p[2]
    propinserts['city'] = p[3]
    propinserts['state'] = p[4]
    propinserts['zip'] = p[5]
    print(propinserts)
    cursor = db.cursor()
    parid = p[1]
    propid = p[0]
    cursor.execute(propperson, (propid, ))
    personid = cursor.fetchall()
    print(p)
    print(repr(p[2]))
    db_owner_map = check_current_owner(parid)
    db_owner_name = db_owner_map['lname']
    db_owner_personid = db_owner_map['personid']
    print(personid)
    rawhtml = get_county_page_for(parid)
    county_owner_name = extract_owner_name(rawhtml)
    print("db: %s **** county: %s" % (db_owner_name, county_owner_name))
    print(db_owner_name == county_owner_name)
    if(db_owner_name != county_owner_name):
        try:
            extract_and_insert_person(rawhtml, county_owner_name, firstavailablepersonid, propinserts)
            for person in personid:
                update_isactive(person[0])
        except Exception:
            print("ERROR extracting and inserting new person\n")
            continue
        try:
            connect_person_to_property(propid, firstavailablepersonid)
        except Exception:
            print("ERROR connecting person to property")
            continue
        firstavailablepersonid += 1
    
    print('\n')
    #extract_and_insert_person(rawhtml, ownername, personid, propinserts)
cursor.close()
# Out:
# 111
# 84142
# {'street': '7241 PRINCETON PL', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170000, '0177P00118000000', '7241 PRINCETON PL', 'PITTSBURGH', 'PA', '15218')
# '7241 PRINCETON PL'
# [('Eric Darsow', 84135), ('Eric Darsow', 84136), ('Eric Darsow', 84137), ('TRUDEAU JOHN B WESTCOTT JAY', 84141)]
# {'lname': 'Eric Darsow', 'personid': 84135}
# [(80000,), (84134,), (84135,), (84136,), (84137,), (84138,), (84139,), (84140,), (84141,)]
# waiting:0.2879070790251802
# Scraping data from county: %s0177P00118000000
# owner_raw_name:TRUDEAU JOHN B     WESTCOTT JAY
# db: Eric Darsow **** county: TRUDEAU JOHN B WESTCOTT JAY
# False
# personid:84142
# --------- extracting owner address ------------
# Scraped:[<span class="DATA" id="lblChangeMail">7241 PRINCETON PL <br/>PITTSBURGH , PA 15218-2038</span>]
# 7241 PRINCETON PL
# city:PITTSBURGH
# state:PA
# zip:15218
# ARE THEY THE SAME??? True
# {'street': '7241 PRINCETON PL', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# SAME ADDRESS
# None
# extracted owner address: 7241 PRINCETON PL PITTSBURGH , PA 15218
# Inserting person data for id: 84142
# person notes:In case of confusion, check autmated record entry with raw text from the county database:TRUDEAU JOHN B WESTCOTT JAY Raw address: [<span class="DATA" id="lblChangeMail">7241 PRINCETON PL <br/>PITTSBURGH , PA 15218-2038</span>]
# ----- committed person owner -----
# ----Old person set to inactive----
# ----Old person set to inactive----
# ----Old person set to inactive----
# ----Old person set to inactive----
# ----Old person set to inactive----
# ----Old person set to inactive----
# ----Old person set to inactive----
# ----Old person set to inactive----
# ----Old person set to inactive----
# ----- connected person owner to property -----
#
#
# {'street': '2623 WOODSTOCK PL', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170001, '0235P00089000000', '2623 WOODSTOCK PL', 'PITTSBURGH', 'PA', '15218')
# '2623 WOODSTOCK PL'
# [('BONAY ANDREW JR & MARGARETTA O', 80001)]
# {'lname': 'BONAY ANDREW JR & MARGARETTA O', 'personid': 80001}
# [(80001,)]
# waiting:0.9180498558620227
# Scraping data from county: %s0235P00089000000
# owner_raw_name:BONAY ANDREW JR &  MARGARETTA O
# db: BONAY ANDREW JR & MARGARETTA O **** county: BONAY ANDREW JR & MARGARETTA O
# True
#
#
# {'street': '7337 MCCLURE AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170002, '0178B00029000000', '7337 MCCLURE AVE', 'PITTSBURGH', 'PA', '15218')
# '7337 MCCLURE AVE'
# [('LINDSAY WILLIAM E', 80002)]
# {'lname': 'LINDSAY WILLIAM E', 'personid': 80002}
# [(80002,)]
# waiting:0.863168200761739
# Scraping data from county: %s0178B00029000000
# owner_raw_name:LINDSAY WILLIAM E
# db: LINDSAY WILLIAM E **** county: LINDSAY WILLIAM E
# True
#
#
# {'street': '2228 S BRADDOCK AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170003, '0178H00296000000', '2228 S BRADDOCK AVE', 'PITTSBURGH', 'PA', '15218')
# '2228 S BRADDOCK AVE'
# [('CHIKA MANAGEMENT COMPANY LLC', 80003)]
# {'lname': 'CHIKA MANAGEMENT COMPANY LLC', 'personid': 80003}
# [(80003,)]
# waiting:0.45244461772753797
# Scraping data from county: %s0178H00296000000
# owner_raw_name:CHIKA MANAGEMENT COMPANY LLC
# db: CHIKA MANAGEMENT COMPANY LLC **** county: CHIKA MANAGEMENT COMPANY LLC
# True
#
#
# {'street': '2624 WOODSTOCK AVE UNIT 4 G-H', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170004, '0235R00153000000', '2624 WOODSTOCK AVE UNIT 4 G-H', 'PITTSBURGH', 'PA', '15218')
# '2624 WOODSTOCK AVE UNIT 4 G-H'
# [('POLISCHUK LEONID & MARIA (W)', 80004)]
# {'lname': 'POLISCHUK LEONID & MARIA (W)', 'personid': 80004}
# [(80004,)]
# waiting:0.11176316808118147
# Scraping data from county: %s0235R00153000000
# owner_raw_name:POLISCHUK LEONID  &  MARIA (W)
# db: POLISCHUK LEONID & MARIA (W) **** county: POLISCHUK LEONID & MARIA (W)
# True
#
#
# {'street': '1212 S BRADDOCK AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170005, '0177B00137000000', '1212 S BRADDOCK AVE', 'PITTSBURGH', 'PA', '15218')
# '1212 S BRADDOCK AVE'
# [('ROGERS JAMES & MARGARET (W)', 80005)]
# {'lname': 'ROGERS JAMES & MARGARET (W)', 'personid': 80005}
# [(80005,)]
# waiting:0.5456308995435497
# Scraping data from county: %s0177B00137000000
# owner_raw_name:ROGERS JAMES &  MARGARET (W)
# db: ROGERS JAMES & MARGARET (W) **** county: ROGERS JAMES & MARGARET (W)
# True
#
#
# {'street': '7912 NEWMEYER ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170006, '0177S00064000000', '7912 NEWMEYER ST', 'PITTSBURGH', 'PA', '15218')
# '7912 NEWMEYER ST'
# [('BARTLETT DAVID MC AFEE', 80006)]
# {'lname': 'BARTLETT DAVID MC AFEE', 'personid': 80006}
# [(80006,)]
# waiting:0.6308999864745592
# Scraping data from county: %s0177S00064000000
# owner_raw_name:BARTLETT DAVID MC AFEE
# db: BARTLETT DAVID MC AFEE **** county: BARTLETT DAVID MC AFEE
# True
#
#
# {'street': '7505 ORMOND ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170007, '0178M00032000000', '7505 ORMOND ST', 'PITTSBURGH', 'PA', '15218')
# '7505 ORMOND ST'
# [('EDMONDS ERIK EDMONDS NIKIA', 80007)]
# {'lname': 'EDMONDS ERIK EDMONDS NIKIA', 'personid': 80007}
# [(80007,)]
# waiting:0.06134311893711941
# Scraping data from county: %s0178M00032000000
# owner_raw_name:EDMONDS ERIK     EDMONDS NIKIA
# db: EDMONDS ERIK EDMONDS NIKIA **** county: EDMONDS ERIK EDMONDS NIKIA
# True
#
#
# {'street': '2101 HAMPTON ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170008, '0234N00226000000', '2101 HAMPTON ST', 'PITTSBURGH', 'PA', '15218')
# '2101 HAMPTON ST'
# [('CRAIG ALBERT M & JOAN B (W)', 80008)]
# {'lname': 'CRAIG ALBERT M & JOAN B (W)', 'personid': 80008}
# [(80008,)]
# waiting:0.7031428405301355
# Scraping data from county: %s0234N00226000000
# owner_raw_name:CRAIG ALBERT M &  JOAN B (W)
# db: CRAIG ALBERT M & JOAN B (W) **** county: CRAIG ALBERT M & JOAN B (W)
# True
#
#
# {'street': '2013 COLUMBIA AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170009, '0177S00210000000', '2013 COLUMBIA AVE', 'PITTSBURGH', 'PA', '15218')
# '2013 COLUMBIA AVE'
# [('DAVIS BILLIE', 80009)]
# {'lname': 'DAVIS BILLIE', 'personid': 80009}
# [(80009,)]
# waiting:0.27383109956558604
# Scraping data from county: %s0177S00210000000
# owner_raw_name:DAVIS BILLIE
# db: DAVIS BILLIE **** county: DAVIS BILLIE
# True
#
#
# {'street': 'LEHIGH ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170010, '0234K00054000000', 'LEHIGH ST', 'PITTSBURGH', 'PA', '15218')
# 'LEHIGH ST'
# [('2239 HAWTHORNE ASSOCIATES LP', 80010)]
# {'lname': '2239 HAWTHORNE ASSOCIATES LP', 'personid': 80010}
# [(80010,)]
# waiting:0.7414640643848465
# Scraping data from county: %s0234K00054000000
# owner_raw_name:2239 HAWTHORNE ASSOCIATES LP
# db: 2239 HAWTHORNE ASSOCIATES LP **** county: 2239 HAWTHORNE ASSOCIATES LP
# True
#
#
# {'street': '2218 MANOR AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170011, '0178H00012000000', '2218 MANOR AVE', 'PITTSBURGH', 'PA', '15218')
# '2218 MANOR AVE'
# [('PARASKY VIRGINIA MARIAN & MICHAEL P LASKOWSKI (H)', 80011)]
# {'lname': 'PARASKY VIRGINIA MARIAN & MICHAEL P LASKOWSKI (H)', 'personid': 80011}
# [(80011,)]
# waiting:0.9287446687161319
# Scraping data from county: %s0178H00012000000
# owner_raw_name:PARASKY VIRGINIA MARIAN &  MICHAEL P   LASKOWSKI (H)
# db: PARASKY VIRGINIA MARIAN & MICHAEL P LASKOWSKI (H) **** county: PARASKY VIRGINIA MARIAN & MICHAEL P LASKOWSKI (H)
# True
#
#
# {'street': '1918 MONONGAHELA AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170012, '0178C00141000000', '1918 MONONGAHELA AVE', 'PITTSBURGH', 'PA', '15218')
# '1918 MONONGAHELA AVE'
# [('MARTINO RUDOLPH', 80012)]
# {'lname': 'MARTINO RUDOLPH', 'personid': 80012}
# [(80012,)]
# waiting:0.303320384312154
# Scraping data from county: %s0178C00141000000
# owner_raw_name:MARTINO RUDOLPH
# db: MARTINO RUDOLPH **** county: MARTINO RUDOLPH
# True
#
#
# {'street': '7900 LLOYD AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170013, '0234P00030000000', '7900 LLOYD AVE', 'PITTSBURGH', 'PA', '15218')
# '7900 LLOYD AVE'
# [('EDWARDS PAUL C & DELEASE A (W)', 80013)]
# {'lname': 'EDWARDS PAUL C & DELEASE A (W)', 'personid': 80013}
# [(80013,)]
# waiting:0.5453914301182284
# Scraping data from county: %s0234P00030000000
# owner_raw_name:EDWARDS PAUL C &  DELEASE A (W)
# db: EDWARDS PAUL C & DELEASE A (W) **** county: EDWARDS PAUL C & DELEASE A (W)
# True
#
#
# {'street': '2031 MONROE ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170014, '0178G00060000000', '2031 MONROE ST', 'PITTSBURGH', 'PA', '15218')
# '2031 MONROE ST'
# [('PALANGIO VERA D (TRUSTEE) (UNDER WILL OF FRANK M PALANGIO) MAKSIMCHUK THERESA ANN (TRUSTEE)(UNDER WILL OF FRANK M PALANGIO)PALANGIOANTHONY J (TRUSTEE)(UNDER WILL OF FRANK J PALANGIO)', 80014)]
# {'lname': 'PALANGIO VERA D (TRUSTEE) (UNDER WILL OF FRANK M PALANGIO) MAKSIMCHUK THERESA ANN (TRUSTEE)(UNDER WILL OF FRANK M PALANGIO)PALANGIOANTHONY J (TRUSTEE)(UNDER WILL OF FRANK J PALANGIO)', 'personid': 80014}
# [(80014,)]
# waiting:0.761564188414103
# Scraping data from county: %s0178G00060000000
# owner_raw_name:PALANGIO VERA D (TRUSTEE)   (UNDER WILL OF FRANK M PALANGIO)   MAKSIMCHUK THERESA ANN (TRUSTEE)(UNDER WILL OF FRANK M PALANGIO)PALANGIOANTHONY J (TRUSTEE)(UNDER WILL OF FRANK J PALANGIO)
# db: PALANGIO VERA D (TRUSTEE) (UNDER WILL OF FRANK M PALANGIO) MAKSIMCHUK THERESA ANN (TRUSTEE)(UNDER WILL OF FRANK M PALANGIO)PALANGIOANTHONY J (TRUSTEE)(UNDER WILL OF FRANK J PALANGIO) **** county: PALANGIO VERA D (TRUSTEE) (UNDER WILL OF FRANK M PALANGIO) MAKSIMCHUK THERESA ANN (TRUSTEE)(UNDER WILL OF FRANK M PALANGIO)PALANGIOANTHONY J (TRUSTEE)(UNDER WILL OF FRANK J PALANGIO)
# True
#
#
# {'street': '2234 S BRADDOCK AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170015, '0178H00300000000', '2234 S BRADDOCK AVE', 'PITTSBURGH', 'PA', '15218')
# '2234 S BRADDOCK AVE'
# [('WELSH PAMELA A NEDEL NICHOLAS WILLIAM', 80015)]
# {'lname': 'WELSH PAMELA A NEDEL NICHOLAS WILLIAM', 'personid': 80015}
# [(80015,)]
# waiting:0.7466642950471261
# Scraping data from county: %s0178H00300000000
# owner_raw_name:WELSH PAMELA A     NEDEL NICHOLAS WILLIAM
# db: WELSH PAMELA A NEDEL NICHOLAS WILLIAM **** county: WELSH PAMELA A NEDEL NICHOLAS WILLIAM
# True
#
#
# {'street': '2320 MANOR AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170016, '0235E00211000000', '2320 MANOR AVE', 'PITTSBURGH', 'PA', '15218')
# '2320 MANOR AVE'
# [('3 BROTHERS PROPERTIES LLC', 80016)]
# {'lname': '3 BROTHERS PROPERTIES LLC', 'personid': 80016}
# [(80016,)]
# waiting:0.5253339247703444
# Scraping data from county: %s0235E00211000000
# owner_raw_name:3 BROTHERS PROPERTIES LLC
# db: 3 BROTHERS PROPERTIES LLC **** county: 3 BROTHERS PROPERTIES LLC
# True
#
#
# {'street': '8206 WESTMORELAND AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170017, '0234J00166000000', '8206 WESTMORELAND AVE', 'PITTSBURGH', 'PA', '15218')
# '8206 WESTMORELAND AVE'
# [('IDUCOVICH KATHLEEN S', 80017)]
# {'lname': 'IDUCOVICH KATHLEEN S', 'personid': 80017}
# [(80017,)]
# waiting:0.7624452572163968
# Scraping data from county: %s0234J00166000000
# owner_raw_name:IDUCOVICH KATHLEEN S
# db: IDUCOVICH KATHLEEN S **** county: IDUCOVICH KATHLEEN S
# True
#
#
# {'street': '1329 MILTON ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170018, '0177F00202000000', '1329 MILTON ST', 'PITTSBURGH', 'PA', '15218')
# '1329 MILTON ST'
# [('ALMANZAR JUAN DE JESUS III KAYSER MORGAN T', 80018)]
# {'lname': 'ALMANZAR JUAN DE JESUS III KAYSER MORGAN T', 'personid': 80018}
# [(80018,)]
# waiting:0.5372815285456328
# Scraping data from county: %s0177F00202000000
# owner_raw_name:ALMANZAR JUAN DE JESUS III     KAYSER MORGAN T
# db: ALMANZAR JUAN DE JESUS III KAYSER MORGAN T **** county: ALMANZAR JUAN DE JESUS III KAYSER MORGAN T
# True
#
#
# {'street': '7813 SAILOR PL', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170019, '0177S00122000000', '7813 SAILOR PL', 'PITTSBURGH', 'PA', '15218')
# '7813 SAILOR PL'
# [('ALLEGHENY BC LP', 80019)]
# {'lname': 'ALLEGHENY BC LP', 'personid': 80019}
# [(80019,)]
# waiting:0.619888325863005
# Scraping data from county: %s0177S00122000000
# owner_raw_name:ALLEGHENY BC LP
# db: ALLEGHENY BC LP **** county: ALLEGHENY BC LP
# True
#
#
# {'street': '2114 NOBLE ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170020, '0178H00179000100', '2114 NOBLE ST', 'PITTSBURGH', 'PA', '15218')
# '2114 NOBLE ST'
# [('GOODFELLOW DEBORAH L', 80020)]
# {'lname': 'GOODFELLOW DEBORAH L', 'personid': 80020}
# [(80020,)]
# waiting:0.4031417891967648
# Scraping data from county: %s0178H00179000100
# owner_raw_name:GOODFELLOW DEBORAH L
# db: GOODFELLOW DEBORAH L **** county: GOODFELLOW DEBORAH L
# True
#
#
# {'street': '5 FARKAS PL', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170021, '0235P00006000001', '5 FARKAS PL', 'PITTSBURGH', 'PA', '15218')
# '5 FARKAS PL'
# [('YOCKEY BARBARA A YOCKEY JACOB A', 80021)]
# {'lname': 'YOCKEY BARBARA A YOCKEY JACOB A', 'personid': 80021}
# [(80021,)]
# waiting:0.14984509140798674
# Scraping data from county: %s0235P00006000001
# owner_raw_name:YOCKEY BARBARA A     YOCKEY JACOB A
# db: YOCKEY BARBARA A YOCKEY JACOB A **** county: YOCKEY BARBARA A YOCKEY JACOB A
# True
#
#
# {'street': '2531 DELAWARE AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170022, '0235B00004000000', '2531 DELAWARE AVE', 'PITTSBURGH', 'PA', '15218')
# '2531 DELAWARE AVE'
# [('EVANS WENDY E', 80022)]
# {'lname': 'EVANS WENDY E', 'personid': 80022}
# [(80022,)]
# waiting:0.6397012148364795
# Scraping data from county: %s0235B00004000000
# owner_raw_name:EVANS WENDY E
# db: EVANS WENDY E **** county: EVANS WENDY E
# True
#
#
# {'street': '1424 MACON AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170023, '0177K00021000000', '1424 MACON AVE', 'PITTSBURGH', 'PA', '15218')
# '1424 MACON AVE'
# [('SHORT STEPHANIE A ENGLISH COREY J', 80023)]
# {'lname': 'SHORT STEPHANIE A ENGLISH COREY J', 'personid': 80023}
# [(80023,)]
# waiting:0.4472798245972138
# Scraping data from county: %s0177K00021000000
# owner_raw_name:SHORT STEPHANIE A     ENGLISH COREY J
# db: SHORT STEPHANIE A ENGLISH COREY J **** county: SHORT STEPHANIE A ENGLISH COREY J
# True
#
#
# {'street': '7725 FRANCIS ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170024, '0178D00064000000', '7725 FRANCIS ST', 'PITTSBURGH', 'PA', '15218')
# '7725 FRANCIS ST'
# [('BUCCIARELLI THOMAS W & MAGDALEN A (W) BUCCIARELLI TIMOTHY G', 80024)]
# {'lname': 'BUCCIARELLI THOMAS W & MAGDALEN A (W) BUCCIARELLI TIMOTHY G', 'personid': 80024}
# [(80024,)]
# waiting:0.6206688831045392
# Scraping data from county: %s0178D00064000000
# owner_raw_name:BUCCIARELLI THOMAS W &  MAGDALEN A (W)     BUCCIARELLI TIMOTHY G
# db: BUCCIARELLI THOMAS W & MAGDALEN A (W) BUCCIARELLI TIMOTHY G **** county: BUCCIARELLI THOMAS W & MAGDALEN A (W) BUCCIARELLI TIMOTHY G
# True
#
#
# {'street': 'LOCUST ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170025, '0178D00158000000', 'LOCUST ST', 'PITTSBURGH', 'PA', '15218')
# 'LOCUST ST'
# [('BEY MACASEA', 80025)]
# {'lname': 'BEY MACASEA', 'personid': 80025}
# [(80025,)]
# waiting:0.34425603290264817
# Scraping data from county: %s0178D00158000000
# owner_raw_name:BEY MACASEA
# db: BEY MACASEA **** county: BEY MACASEA
# True
#
#
# {'street': 'DELAWARE AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170026, '0235B00035000000', 'DELAWARE AVE', 'PITTSBURGH', 'PA', '15218')
# 'DELAWARE AVE'
# [('BOMRER MARY F', 80026)]
# {'lname': 'BOMRER MARY F', 'personid': 80026}
# [(80026,)]
# waiting:0.47966794675160507
# Scraping data from county: %s0235B00035000000
# owner_raw_name:BOMRER MARY F
# db: BOMRER MARY F **** county: BOMRER MARY F
# True
#
#
# {'street': 'LILMONT DR', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170027, '0235R00230000000', 'LILMONT DR', 'PITTSBURGH', 'PA', '15218')
# 'LILMONT DR'
# [('SCHEIB RODGER & BETTY ANN (W)', 80027)]
# {'lname': 'SCHEIB RODGER & BETTY ANN (W)', 'personid': 80027}
# [(80027,)]
# waiting:0.09726272674210701
# Scraping data from county: %s0235R00230000000
# owner_raw_name:SCHEIB RODGER &  BETTY ANN (W)
# db: SCHEIB RODGER & BETTY ANN (W) **** county: SCHEIB RODGER & BETTY ANN (W)
# True
#
#
# {'street': '7108 HARRISON AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170028, '0178A00286000000', '7108 HARRISON AVE', 'PITTSBURGH', 'PA', '15218')
# '7108 HARRISON AVE'
# [('CAMPBELL BARBARA M', 80028)]
# {'lname': 'CAMPBELL BARBARA M', 'personid': 80028}
# [(80028,)]
# waiting:0.10554129027535297
# Scraping data from county: %s0178A00286000000
# owner_raw_name:CAMPBELL BARBARA M
# db: CAMPBELL BARBARA M **** county: CAMPBELL BARBARA M
# True
#
#
# {'street': 'CHALMERS ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170029, '0234P00338000000', 'CHALMERS ST', 'PITTSBURGH', 'PA', '15218')
# 'CHALMERS ST'
# [('CHALMERS STREET ASSOCIATES INC', 80029)]
# {'lname': 'CHALMERS STREET ASSOCIATES INC', 'personid': 80029}
# [(80029,)]
# waiting:0.13591979824386868
# Scraping data from county: %s0234P00338000000
# owner_raw_name:CHALMERS STREET ASSOCIATES INC
# db: CHALMERS STREET ASSOCIATES INC **** county: CHALMERS STREET ASSOCIATES INC
# True
#
#
# {'street': 'MANOR AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170030, '0235E00193000000', 'MANOR AVE', 'PITTSBURGH', 'PA', '15218')
# 'MANOR AVE'
# [('REDEVELOPMENT AUTH OF ALLEGHENY COUNTY', 80030)]
# {'lname': 'REDEVELOPMENT AUTH OF ALLEGHENY COUNTY', 'personid': 80030}
# [(80030,)]
# waiting:0.31264344377499953
# Scraping data from county: %s0235E00193000000
# owner_raw_name:REDEVELOPMENT AUTH OF ALLEGHENY COUNTY
# db: REDEVELOPMENT AUTH OF ALLEGHENY COUNTY **** county: REDEVELOPMENT AUTH OF ALLEGHENY COUNTY
# True
#
#
# {'street': '7908 LLOYD AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170031, '0234P00040000000', '7908 LLOYD AVE', 'PITTSBURGH', 'PA', '15218')
# '7908 LLOYD AVE'
# [('MADIA RONALD A', 80031)]
# {'lname': 'MADIA RONALD A', 'personid': 80031}
# [(80031,)]
# waiting:0.10462042263891069
# Scraping data from county: %s0234P00040000000
# owner_raw_name:MADIA RONALD A
# db: MADIA RONALD A **** county: MADIA RONALD A
# True
#
#
# {'street': '2319 HAWTHORNE AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170032, '0235E00050000000', '2319 HAWTHORNE AVE', 'PITTSBURGH', 'PA', '15218')
# '2319 HAWTHORNE AVE'
# [('INMAN JOSHUA', 80032)]
# {'lname': 'INMAN JOSHUA', 'personid': 80032}
# [(80032,)]
# waiting:0.041062654933542664
# Scraping data from county: %s0235E00050000000
# owner_raw_name:INMAN JOSHUA
# db: INMAN JOSHUA **** county: INMAN JOSHUA
# True
#
#
# {'street': '2012 MONONGAHELA AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170033, '0178G00137000100', '2012 MONONGAHELA AVE', 'PITTSBURGH', 'PA', '15218')
# '2012 MONONGAHELA AVE'
# [('MIA & ZI LLC', 80033)]
# {'lname': 'MIA & ZI LLC', 'personid': 80033}
# [(80033,)]
# waiting:0.7523213905162004
# Scraping data from county: %s0178G00137000100
# owner_raw_name:MIA &  ZI LLC
# db: MIA & ZI LLC **** county: MIA & ZI LLC
# True
#
#
# {'street': '2435 S BRADDOCK AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170034, '0235J00040000000', '2435 S BRADDOCK AVE', 'PITTSBURGH', 'PA', '15218')
# '2435 S BRADDOCK AVE'
# [('LANDUCCI RONALD J SR', 80034)]
# {'lname': 'LANDUCCI RONALD J SR', 'personid': 80034}
# [(80034,)]
# waiting:0.35342060627858984
# Scraping data from county: %s0235J00040000000
# owner_raw_name:LANDUCCI RONALD J SR
# db: LANDUCCI RONALD J SR **** county: LANDUCCI RONALD J SR
# True
#
#
# {'street': '2258 HAWTHORNE AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170035, '0235E00016000000', '2258 HAWTHORNE AVE', 'PITTSBURGH', 'PA', '15218')
# '2258 HAWTHORNE AVE'
# [('SMITH WESLEY BRANDON SR', 80035)]
# {'lname': 'SMITH WESLEY BRANDON SR', 'personid': 80035}
# [(80035,)]
# waiting:0.4088822243684156
# Scraping data from county: %s0235E00016000000
# owner_raw_name:SMITH WESLEY BRANDON SR
# db: SMITH WESLEY BRANDON SR **** county: SMITH WESLEY BRANDON SR
# True
#
#
# {'street': '1101 LACLAIR ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170036, '0177A00028000000', '1101 LACLAIR ST', 'PITTSBURGH', 'PA', '15218')
# '1101 LACLAIR ST'
# [('WETZEL KAY L', 80036)]
# {'lname': 'WETZEL KAY L', 'personid': 80036}
# [(80036,)]
# waiting:0.5298403339081341
# Scraping data from county: %s0177A00028000000
# owner_raw_name:WETZEL KAY L
# db: WETZEL KAY L **** county: WETZEL KAY L
# True
#
#
# {'street': '1217 MILTON ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170037, '0177B00201000000', '1217 MILTON ST', 'PITTSBURGH', 'PA', '15218')
# '1217 MILTON ST'
# [('BATISTA KENNETH & MARTHA HELON HALL (W)', 80037)]
# {'lname': 'BATISTA KENNETH & MARTHA HELON HALL (W)', 'personid': 80037}
# [(80037,)]
# waiting:0.7258901314745576
# Scraping data from county: %s0177B00201000000
# owner_raw_name:BATISTA KENNETH &  MARTHA HELON HALL (W)
# db: BATISTA KENNETH & MARTHA HELON HALL (W) **** county: BATISTA KENNETH & MARTHA HELON HALL (W)
# True
#
#
# {'street': '60 LILMONT DR', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170038, '0235G00002000000', '60 LILMONT DR', 'PITTSBURGH', 'PA', '15218')
# '60 LILMONT DR'
# [('NELSON BETH M', 80038)]
# {'lname': 'NELSON BETH M', 'personid': 80038}
# [(80038,)]
# waiting:0.017842562810755913
# Scraping data from county: %s0235G00002000000
# owner_raw_name:NELSON BETH M
# db: NELSON BETH M **** county: NELSON BETH M
# True
#
#
# {'street': '7139 HARRISON AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170039, '0178A00222000000', '7139 HARRISON AVE', 'PITTSBURGH', 'PA', '15218')
# '7139 HARRISON AVE'
# [('SEMINARA JOSEPH', 80039)]
# {'lname': 'SEMINARA JOSEPH', 'personid': 80039}
# [(80039,)]
# waiting:0.6108805895951939
# Scraping data from county: %s0178A00222000000
# owner_raw_name:SEMINARA JOSEPH
# db: SEMINARA JOSEPH **** county: SEMINARA JOSEPH
# True
#
#
# {'street': '1912 HANOVER ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170040, '0178F00180000000', '1912 HANOVER ST', 'PITTSBURGH', 'PA', '15218')
# '1912 HANOVER ST'
# [('HALLER MATTHEW D & LORI J (W)', 80040)]
# {'lname': 'HALLER MATTHEW D & LORI J (W)', 'personid': 80040}
# [(80040,)]
# waiting:0.7602083697271236
# Scraping data from county: %s0178F00180000000
# owner_raw_name:HALLER MATTHEW D &  LORI J (W)
# db: HALLER MATTHEW D & LORI J (W) **** county: HALLER MATTHEW D & LORI J (W)
# True
#
#
# {'street': '7932 NEWMEYER ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170041, '0177M00155000000', '7932 NEWMEYER ST', 'PITTSBURGH', 'PA', '15218')
# '7932 NEWMEYER ST'
# [('BUNTACK ELENORA', 80041)]
# {'lname': 'BUNTACK ELENORA', 'personid': 80041}
# [(80041,)]
# waiting:0.41335397410587604
# Scraping data from county: %s0177M00155000000
# owner_raw_name:BUNTACK ELENORA
# db: BUNTACK ELENORA **** county: BUNTACK ELENORA
# True
#
#
# {'street': '2101 LLOYD AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170042, '0234J00130000000', '2101 LLOYD AVE', 'PITTSBURGH', 'PA', '15218')
# '2101 LLOYD AVE'
# [('SMETAK DAVID A', 80042)]
# {'lname': 'SMETAK DAVID A', 'personid': 80042}
# [(80042,)]
# waiting:0.3635564724971756
# Scraping data from county: %s0234J00130000000
# owner_raw_name:SMETAK DAVID A
# db: SMETAK DAVID A **** county: SMETAK DAVID A
# True
#
#
# {'street': '2222 MILLIGAN AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170043, '0235A00266000000', '2222 MILLIGAN AVE', 'PITTSBURGH', 'PA', '15218')
# '2222 MILLIGAN AVE'
# [('ALEXANDER THOMAS COMPANY', 80043)]
# {'lname': 'ALEXANDER THOMAS COMPANY', 'personid': 80043}
# [(80043,)]
# waiting:0.422353733002619
# Scraping data from county: %s0235A00266000000
# owner_raw_name:ALEXANDER THOMAS COMPANY
# db: ALEXANDER THOMAS COMPANY **** county: ALEXANDER THOMAS COMPANY
# True
#
#
# {'street': '1825 MONONGAHELA AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170044, '0178C00080000000', '1825 MONONGAHELA AVE', 'PITTSBURGH', 'PA', '15218')
# '1825 MONONGAHELA AVE'
# [('SWISSVALE PRESBYTERIAN CHURCH (THE)', 80044)]
# {'lname': 'SWISSVALE PRESBYTERIAN CHURCH (THE)', 'personid': 80044}
# [(80044,)]
# waiting:0.5106690896209073
# Scraping data from county: %s0178C00080000000
# owner_raw_name:SWISSVALE PRESBYTERIAN CHURCH (THE)
# db: SWISSVALE PRESBYTERIAN CHURCH (THE) **** county: SWISSVALE PRESBYTERIAN CHURCH (THE)
# True
#
#
# {'street': '1813 COMMERCIAL ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170045, '0178E00180000000', '1813 COMMERCIAL ST', 'PITTSBURGH', 'PA', '15218')
# '1813 COMMERCIAL ST'
# [('ORFITELLI GILDA', 80045)]
# {'lname': 'ORFITELLI GILDA', 'personid': 80045}
# [(80045,)]
# waiting:0.7194643034660918
# Scraping data from county: %s0178E00180000000
# owner_raw_name:ORFITELLI GILDA
# db: ORFITELLI GILDA **** county: ORFITELLI GILDA
# True
#
#
# {'street': '1605 MIRIAM ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170046, '0177R00066000000', '1605 MIRIAM ST', 'PITTSBURGH', 'PA', '15218')
# '1605 MIRIAM ST'
# [('YODER CALVIN A', 80046)]
# {'lname': 'YODER CALVIN A', 'personid': 80046}
# [(80046,)]
# waiting:0.13518442698413802
# Scraping data from county: %s0177R00066000000
# owner_raw_name:YODER CALVIN A
# db: YODER CALVIN A **** county: YODER CALVIN A
# True
#
#
# {'street': '1525 MANSION PL', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170047, '0178E00163000000', '1525 MANSION PL', 'PITTSBURGH', 'PA', '15218')
# '1525 MANSION PL'
# [('LEVINE LOUIS PAUL & KARLA JON THARP', 80047)]
# {'lname': 'LEVINE LOUIS PAUL & KARLA JON THARP', 'personid': 80047}
# [(80047,)]
# waiting:0.9784908037154649
# Scraping data from county: %s0178E00163000000
# owner_raw_name:LEVINE LOUIS PAUL &  KARLA JON THARP
# db: LEVINE LOUIS PAUL & KARLA JON THARP **** county: LEVINE LOUIS PAUL & KARLA JON THARP
# True
#
#
# {'street': '7464 DELMAR WAY', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170048, '0178C00002000000', '7464 DELMAR WAY', 'PITTSBURGH', 'PA', '15218')
# '7464 DELMAR WAY'
# [('FULL SHANNON', 80048)]
# {'lname': 'FULL SHANNON', 'personid': 80048}
# [(80048,)]
# waiting:0.8927725822468696
# Scraping data from county: %s0178C00002000000
# owner_raw_name:FULL SHANNON
# db: FULL SHANNON **** county: FULL SHANNON
# True
#
#
# {'street': '7907 LLOYD AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170049, '0234P00026000000', '7907 LLOYD AVE', 'PITTSBURGH', 'PA', '15218')
# '7907 LLOYD AVE'
# [('FAIZIEV BAHADIR & MIRSALIKOV A BARNO (W)', 80049)]
# {'lname': 'FAIZIEV BAHADIR & MIRSALIKOV A BARNO (W)', 'personid': 80049}
# [(80049,)]
# waiting:0.3439351027627533
# Scraping data from county: %s0234P00026000000
# owner_raw_name:FAIZIEV BAHADIR &  MIRSALIKOV A BARNO (W)
# db: FAIZIEV BAHADIR & MIRSALIKOV A BARNO (W) **** county: FAIZIEV BAHADIR & MIRSALIKOV A BARNO (W)
# True
#
#
# {'street': 'HAWTHORNE AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170050, '0235E00055000000', 'HAWTHORNE AVE', 'PITTSBURGH', 'PA', '15218')
# 'HAWTHORNE AVE'
# [('BORO OF SWISSVALE', 80050)]
# {'lname': 'BORO OF SWISSVALE', 'personid': 80050}
# [(80050,)]
# waiting:0.1380897588076293
# Scraping data from county: %s0235E00055000000
# owner_raw_name:BORO OF SWISSVALE
# db: BORO OF SWISSVALE **** county: BORO OF SWISSVALE
# True
#
#
# {'street': '106 LONGFELLOW CT', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170051, '0178B00285000600', '106 LONGFELLOW CT', 'PITTSBURGH', 'PA', '15218')
# '106 LONGFELLOW CT'
# [('JEFFERSON CHERYLE L', 80051)]
# {'lname': 'JEFFERSON CHERYLE L', 'personid': 80051}
# [(80051,)]
# waiting:0.7153177533240159
# Scraping data from county: %s0178B00285000600
# owner_raw_name:JEFFERSON CHERYLE L
# db: JEFFERSON CHERYLE L **** county: JEFFERSON CHERYLE L
# True
#
#
# {'street': '2318 MANOR AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170052, '0235E00206000000', '2318 MANOR AVE', 'PITTSBURGH', 'PA', '15218')
# '2318 MANOR AVE'
# [('CARTER JON S & CELESTE R (W)', 80052)]
# {'lname': 'CARTER JON S & CELESTE R (W)', 'personid': 80052}
# [(80052,)]
# waiting:0.435794312887257
# Scraping data from county: %s0235E00206000000
# owner_raw_name:CARTER JON S &  CELESTE R (W)
# db: CARTER JON S & CELESTE R (W) **** county: CARTER JON S & CELESTE R (W)
# True
#
#
# {'street': '2210 MILLIGAN AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170053, '0235A00272000000', '2210 MILLIGAN AVE', 'PITTSBURGH', 'PA', '15218')
# '2210 MILLIGAN AVE'
# [('SODERBERG CLIFFORD O & EVELYN C', 80053)]
# {'lname': 'SODERBERG CLIFFORD O & EVELYN C', 'personid': 80053}
# [(80053,)]
# waiting:0.4227630395956866
# Scraping data from county: %s0235A00272000000
# owner_raw_name:SODERBERG CLIFFORD O &  EVELYN C
# db: SODERBERG CLIFFORD O & EVELYN C **** county: SODERBERG CLIFFORD O & EVELYN C
# True
#
#
# {'street': '7311 WHIPPLE ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170054, '0177P00071000000', '7311 WHIPPLE ST', 'PITTSBURGH', 'PA', '15218')
# '7311 WHIPPLE ST'
# [('CROCE DANIEL C & LARA (W)', 80054)]
# {'lname': 'CROCE DANIEL C & LARA (W)', 'personid': 80054}
# [(80054,)]
# waiting:0.2980832573344052
# Scraping data from county: %s0177P00071000000
# owner_raw_name:CROCE DANIEL C &  LARA (W)
# db: CROCE DANIEL C & LARA (W) **** county: CROCE DANIEL C & LARA (W)
# True
#
#
# {'street': '2121 COLUMBIA AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170055, '0234N00276000000', '2121 COLUMBIA AVE', 'PITTSBURGH', 'PA', '15218')
# '2121 COLUMBIA AVE'
# [('AHEARN SARAH & BRIAN (H)', 80055)]
# {'lname': 'AHEARN SARAH & BRIAN (H)', 'personid': 80055}
# [(80055,)]
# waiting:0.196152770458354
# Scraping data from county: %s0234N00276000000
# owner_raw_name:AHEARN SARAH &  BRIAN (H)
# db: AHEARN SARAH & BRIAN (H) **** county: AHEARN SARAH & BRIAN (H)
# True
#
#
# {'street': '2506 WOODSTOCK AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170056, '0235N00354000000', '2506 WOODSTOCK AVE', 'PITTSBURGH', 'PA', '15218')
# '2506 WOODSTOCK AVE'
# [('RUFFOLO MARK C', 80056)]
# {'lname': 'RUFFOLO MARK C', 'personid': 80056}
# [(80056,)]
# waiting:0.24808739763699272
# Scraping data from county: %s0235N00354000000
# owner_raw_name:RUFFOLO MARK C
# db: RUFFOLO MARK C **** county: RUFFOLO MARK C
# True
#
#
# {'street': '2048 MONONGAHELA AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170057, '0178G00173000000', '2048 MONONGAHELA AVE', 'PITTSBURGH', 'PA', '15218')
# '2048 MONONGAHELA AVE'
# [('FISHER ANDREW R', 80057)]
# {'lname': 'FISHER ANDREW R', 'personid': 80057}
# [(80057,)]
# waiting:0.6179456796409519
# Scraping data from county: %s0178G00173000000
# owner_raw_name:FISHER ANDREW R
# db: FISHER ANDREW R **** county: FISHER ANDREW R
# True
#
#
# {'street': '7813 UNION AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170058, '0177S00162000000', '7813 UNION AVE', 'PITTSBURGH', 'PA', '15218')
# '7813 UNION AVE'
# [('LOWRY WILLIAM FRANK', 80058)]
# {'lname': 'LOWRY WILLIAM FRANK', 'personid': 80058}
# [(80058,)]
# waiting:0.6202463769174024
# Scraping data from county: %s0177S00162000000
# owner_raw_name:LOWRY WILLIAM FRANK
# db: LOWRY WILLIAM FRANK **** county: LOWRY WILLIAM FRANK
# True
#
#
# {'street': '7542 ARDMORE ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170059, '0178H00268000000', '7542 ARDMORE ST', 'PITTSBURGH', 'PA', '15218')
# '7542 ARDMORE ST'
# [('WOS ANTOINETTE M MCFARLAND WILLIAM WMCFARLAND DONALD K', 80059)]
# {'lname': 'WOS ANTOINETTE M MCFARLAND WILLIAM WMCFARLAND DONALD K', 'personid': 80059}
# [(80059,)]
# waiting:0.1481098747664189
# Scraping data from county: %s0178H00268000000
# owner_raw_name:WOS ANTOINETTE M     MCFARLAND WILLIAM WMCFARLAND DONALD K
# db: WOS ANTOINETTE M MCFARLAND WILLIAM WMCFARLAND DONALD K **** county: WOS ANTOINETTE M MCFARLAND WILLIAM WMCFARLAND DONALD K
# True
#
#
# {'street': '7435 DUQUESNE AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170060, '0178H00151000000', '7435 DUQUESNE AVE', 'PITTSBURGH', 'PA', '15218')
# '7435 DUQUESNE AVE'
# [('LANEY WALTER L & LORETTA E', 80060)]
# {'lname': 'LANEY WALTER L & LORETTA E', 'personid': 80060}
# [(80060,)]
# waiting:0.014320737397894856
# Scraping data from county: %s0178H00151000000
# owner_raw_name:LANEY WALTER L &  LORETTA E
# db: LANEY WALTER L & LORETTA E **** county: LANEY WALTER L & LORETTA E
# True
#
#
# {'street': '7717 FRANCIS ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170061, '0177S00234000000', '7717 FRANCIS ST', 'PITTSBURGH', 'PA', '15218')
# '7717 FRANCIS ST'
# [('PAWLOWSKI NICOLETTE', 80061)]
# {'lname': 'PAWLOWSKI NICOLETTE', 'personid': 80061}
# [(80061,)]
# waiting:0.9368054355894053
# Scraping data from county: %s0177S00234000000
# owner_raw_name:PAWLOWSKI NICOLETTE
# db: PAWLOWSKI NICOLETTE **** county: PAWLOWSKI NICOLETTE
# True
#
#
# {'street': '7026 BLACKHAWK ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170062, '0178A00189000000', '7026 BLACKHAWK ST', 'PITTSBURGH', 'PA', '15218')
# '7026 BLACKHAWK ST'
# [('HAGUE ELIZABETH H', 80062)]
# {'lname': 'HAGUE ELIZABETH H', 'personid': 80062}
# [(80062,)]
# waiting:0.6957855728098021
# Scraping data from county: %s0178A00189000000
# owner_raw_name:HAGUE ELIZABETH H
# db: HAGUE ELIZABETH H **** county: HAGUE ELIZABETH H
# True
#
#
# {'street': '7511 HUTCHINSON ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170063, '0177A00018000000', '7511 HUTCHINSON ST', 'PITTSBURGH', 'PA', '15218')
# '7511 HUTCHINSON ST'
# [('BRAHAN JEFFREY P & KATHERINE K (W)', 80063)]
# {'lname': 'BRAHAN JEFFREY P & KATHERINE K (W)', 'personid': 80063}
# [(80063,)]
# waiting:0.8271743247356733
# Scraping data from county: %s0177A00018000000
# owner_raw_name:BRAHAN JEFFREY P &  KATHERINE K (W)
# db: BRAHAN JEFFREY P & KATHERINE K (W) **** county: BRAHAN JEFFREY P & KATHERINE K (W)
# True
#
#
# {'street': '2038 MONONGAHELA AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170064, '0178G00178000000', '2038 MONONGAHELA AVE', 'PITTSBURGH', 'PA', '15218')
# '2038 MONONGAHELA AVE'
# [('SCOTT CAPRICE K', 80064)]
# {'lname': 'SCOTT CAPRICE K', 'personid': 80064}
# [(80064,)]
# waiting:0.8796454252483371
# Scraping data from county: %s0178G00178000000
# owner_raw_name:SCOTT CAPRICE K
# db: SCOTT CAPRICE K **** county: SCOTT CAPRICE K
# True
#
#
# {'street': '7300 SCHLEY AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170065, '0178K00064000000', '7300 SCHLEY AVE', 'PITTSBURGH', 'PA', '15218')
# '7300 SCHLEY AVE'
# [('BOSKO GERARD P STROUP DENISE C', 80065)]
# {'lname': 'BOSKO GERARD P STROUP DENISE C', 'personid': 80065}
# [(80065,)]
# waiting:0.4954948706720199
# Scraping data from county: %s0178K00064000000
# owner_raw_name:BOSKO GERARD P     STROUP DENISE C
# db: BOSKO GERARD P STROUP DENISE C **** county: BOSKO GERARD P STROUP DENISE C
# True
#
#
# {'street': '7475 DELMAR WAY', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170066, '0177R00287000000', '7475 DELMAR WAY', 'PITTSBURGH', 'PA', '15218')
# '7475 DELMAR WAY'
# [('MCQUADE ANNE MARIE', 80066)]
# {'lname': 'MCQUADE ANNE MARIE', 'personid': 80066}
# [(80066,)]
# waiting:0.7302529011487312
# Scraping data from county: %s0177R00287000000
# owner_raw_name:MCQUADE ANNE MARIE
# db: MCQUADE ANNE MARIE **** county: MCQUADE ANNE MARIE
# True
#
#
# {'street': '7904 WESTMORELAND AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170067, '0234N00236000000', '7904 WESTMORELAND AVE', 'PITTSBURGH', 'PA', '15218')
# '7904 WESTMORELAND AVE'
# [('MALONEY HELEN E MALONEY PEGGY A', 80067)]
# {'lname': 'MALONEY HELEN E MALONEY PEGGY A', 'personid': 80067}
# [(80067,)]
# waiting:0.9892938181770798
# Scraping data from county: %s0234N00236000000
# owner_raw_name:MALONEY HELEN E     MALONEY PEGGY A
# db: MALONEY HELEN E MALONEY PEGGY A **** county: MALONEY HELEN E MALONEY PEGGY A
# True
#
#
# {'street': '2114 S BRADDOCK AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170068, '0178H00046000000', '2114 S BRADDOCK AVE', 'PITTSBURGH', 'PA', '15218')
# '2114 S BRADDOCK AVE'
# [('THOMAS ALEXANDER CO', 80068)]
# {'lname': 'THOMAS ALEXANDER CO', 'personid': 80068}
# [(80068,)]
# waiting:0.28548339324130956
# Scraping data from county: %s0178H00046000000
# owner_raw_name:THOMAS ALEXANDER CO
# db: THOMAS ALEXANDER CO **** county: THOMAS ALEXANDER CO
# True
#
#
# {'street': '1710 MIRIAM ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170069, '0177R00129000000', '1710 MIRIAM ST', 'PITTSBURGH', 'PA', '15218')
# '1710 MIRIAM ST'
# [('NEPLOTNIK EUGENE Y & OLGA V (W)', 80069)]
# {'lname': 'NEPLOTNIK EUGENE Y & OLGA V (W)', 'personid': 80069}
# [(80069,)]
# waiting:0.4559663444615155
# Scraping data from county: %s0177R00129000000
# owner_raw_name:NEPLOTNIK EUGENE Y &  OLGA V (W)
# db: NEPLOTNIK EUGENE Y & OLGA V (W) **** county: NEPLOTNIK EUGENE Y & OLGA V (W)
# True
#
#
# {'street': '58 LILMONT DR', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170070, '0235G00003000000', '58 LILMONT DR', 'PITTSBURGH', 'PA', '15218')
# '58 LILMONT DR'
# [('WARGOVICH EDWARD R & ANN', 80070)]
# {'lname': 'WARGOVICH EDWARD R & ANN', 'personid': 80070}
# [(80070,)]
# waiting:0.2361106698388794
# Scraping data from county: %s0235G00003000000
# owner_raw_name:WARGOVICH EDWARD R &  ANN
# db: WARGOVICH EDWARD R & ANN **** county: WARGOVICH EDWARD R & ANN
# True
#
#
# {'street': '1400 SMOKEY WOOD DR UNIT D-703', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170071, '0234P00165470300', '1400 SMOKEY WOOD DR UNIT D-703', 'PITTSBURGH', 'PA', '15218')
# '1400 SMOKEY WOOD DR UNIT D-703'
# [('ALLAN JACQUELINE E', 80071)]
# {'lname': 'ALLAN JACQUELINE E', 'personid': 80071}
# [(80071,)]
# waiting:0.3857225538514196
# Scraping data from county: %s0234P00165470300
# owner_raw_name:ALLAN JACQUELINE E
# db: ALLAN JACQUELINE E **** county: ALLAN JACQUELINE E
# True
#
#
# {'street': 'BUENA VISTA ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170072, '0235E00238000000', 'BUENA VISTA ST', 'PITTSBURGH', 'PA', '15218')
# 'BUENA VISTA ST'
# [('GRGICH GRGO & JAGA', 80072)]
# {'lname': 'GRGICH GRGO & JAGA', 'personid': 80072}
# [(80072,)]
# waiting:0.42539099905551747
# Scraping data from county: %s0235E00238000000
# owner_raw_name:GRGICH GRGO  &  JAGA
# db: GRGICH GRGO & JAGA **** county: GRGICH GRGO & JAGA
# True
#
#
# {'street': '7613 CHEYENNE ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170073, '0235E00357000000', '7613 CHEYENNE ST', 'PITTSBURGH', 'PA', '15218')
# '7613 CHEYENNE ST'
# [('ONEAL LEROY D & JOETTA MAE (W)', 80073)]
# {'lname': 'ONEAL LEROY D & JOETTA MAE (W)', 'personid': 80073}
# [(80073,)]
# waiting:0.3362142706757435
# Scraping data from county: %s0235E00357000000
# owner_raw_name:ONEAL LEROY D &  JOETTA MAE (W)
# db: ONEAL LEROY D & JOETTA MAE (W) **** county: ONEAL LEROY D & JOETTA MAE (W)
# True
#
#
# {'street': '7361 DENNISTON AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170074, '0178G00154000000', '7361 DENNISTON AVE', 'PITTSBURGH', 'PA', '15218')
# '7361 DENNISTON AVE'
# [('MORRIS CHERYL', 80074)]
# {'lname': 'MORRIS CHERYL', 'personid': 80074}
# [(80074,)]
# waiting:0.5113874164733135
# Scraping data from county: %s0178G00154000000
# owner_raw_name:MORRIS CHERYL
# db: MORRIS CHERYL **** county: MORRIS CHERYL
# True
#
#
# {'street': 'WILKINS AVE', 'city': 'BRADDOCK', 'state': 'PA', 'zip': '15104'}
# (170075, '0236C00024000000', 'WILKINS AVE', 'BRADDOCK', 'PA', '15104')
# 'WILKINS AVE'
# [('WILLIAMS JOSEPHINE & JOHNSON RUFUS H', 80075)]
# {'lname': 'WILLIAMS JOSEPHINE & JOHNSON RUFUS H', 'personid': 80075}
# [(80075,)]
# waiting:0.3179789872189136
# Scraping data from county: %s0236C00024000000
# owner_raw_name:WILLIAMS JOSEPHINE  &  JOHNSON RUFUS H
# db: WILLIAMS JOSEPHINE & JOHNSON RUFUS H **** county: WILLIAMS JOSEPHINE & JOHNSON RUFUS H
# True
#
#
# {'street': '7203 WHIPPLE ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170076, '0177N00202000000', '7203 WHIPPLE ST', 'PITTSBURGH', 'PA', '15218')
# '7203 WHIPPLE ST'
# [('HOENER JEFFREY C', 80076)]
# {'lname': 'HOENER JEFFREY C', 'personid': 80076}
# [(80076,)]
# waiting:0.10280517720846916
# Scraping data from county: %s0177N00202000000
# owner_raw_name:HOENER JEFFREY C
# db: HOENER JEFFREY C **** county: HOENER JEFFREY C
# True
#
#
# {'street': '6 FARKAS PL', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170077, '0235L00300000000', '6 FARKAS PL', 'PITTSBURGH', 'PA', '15218')
# '6 FARKAS PL'
# [('STANLEY JEFFREY J & JENNIFER L (W)', 80077)]
# {'lname': 'STANLEY JEFFREY J & JENNIFER L (W)', 'personid': 80077}
# [(80077,)]
# waiting:0.8369796386202863
# Scraping data from county: %s0235L00300000000
# owner_raw_name:STANLEY JEFFREY J &  JENNIFER L (W)
# db: STANLEY JEFFREY J & JENNIFER L (W) **** county: STANLEY JEFFREY J & JENNIFER L (W)
# True
#
#
# {'street': '2116 COLUMBIA AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170078, '0235A00079000000', '2116 COLUMBIA AVE', 'PITTSBURGH', 'PA', '15218')
# '2116 COLUMBIA AVE'
# [('TRIVIUM ASSETS LLC', 80078)]
# {'lname': 'TRIVIUM ASSETS LLC', 'personid': 80078}
# [(80078,)]
# waiting:0.20617223160587317
# Scraping data from county: %s0235A00079000000
# owner_raw_name:TRIVIUM ASSETS LLC
# db: TRIVIUM ASSETS LLC **** county: TRIVIUM ASSETS LLC
# True
#
#
# {'street': '113 LILMONT DR', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170079, '0235R00192000000', '113 LILMONT DR', 'PITTSBURGH', 'PA', '15218')
# '113 LILMONT DR'
# [('EZELL JOHN R & KIM R (W)', 80079)]
# {'lname': 'EZELL JOHN R & KIM R (W)', 'personid': 80079}
# [(80079,)]
# waiting:0.40577731132375183
# Scraping data from county: %s0235R00192000000
# owner_raw_name:EZELL JOHN R &  KIM R (W)
# db: EZELL JOHN R & KIM R (W) **** county: EZELL JOHN R & KIM R (W)
# True
#
#
# {'street': '7242 PRINCETON PL', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170080, '0177P00168000000', '7242 PRINCETON PL', 'PITTSBURGH', 'PA', '15218')
# '7242 PRINCETON PL'
# [('RUNCO ELENA M', 80080)]
# {'lname': 'RUNCO ELENA M', 'personid': 80080}
# [(80080,)]
# waiting:0.49991359419229575
# Scraping data from county: %s0177P00168000000
# owner_raw_name:RUNCO ELENA M
# db: RUNCO ELENA M **** county: RUNCO ELENA M
# True
#
#
# {'street': '1640 S BRADDOCK AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170081, '0177R00010000000', '1640 S BRADDOCK AVE', 'PITTSBURGH', 'PA', '15218')
# '1640 S BRADDOCK AVE'
# [("O'TOOLE DANIEL P", 80081)]
# {'lname': "O'TOOLE DANIEL P", 'personid': 80081}
# [(80081,)]
# waiting:0.3031795408867005
# Scraping data from county: %s0177R00010000000
# owner_raw_name:O'TOOLE DANIEL P
# db: O'TOOLE DANIEL P **** county: O'TOOLE DANIEL P
# True
#
#
# {'street': '7539 ARDMORE ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170082, '0178H00272000000', '7539 ARDMORE ST', 'PITTSBURGH', 'PA', '15218')
# '7539 ARDMORE ST'
# [('PRICE WILLIAM C JR & MARY R (W)', 80082)]
# {'lname': 'PRICE WILLIAM C JR & MARY R (W)', 'personid': 80082}
# [(80082,)]
# waiting:0.3657527748309629
# Scraping data from county: %s0178H00272000000
# owner_raw_name:PRICE WILLIAM C JR &  MARY R (W)
# db: PRICE WILLIAM C JR & MARY R (W) **** county: PRICE WILLIAM C JR & MARY R (W)
# True
#
#
# {'street': '7334 WHIPPLE ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170083, '0177P00230000000', '7334 WHIPPLE ST', 'PITTSBURGH', 'PA', '15218')
# '7334 WHIPPLE ST'
# [('LAROSA EMILY C', 80083)]
# {'lname': 'LAROSA EMILY C', 'personid': 80083}
# [(80083,)]
# waiting:0.32444151131768917
# Scraping data from county: %s0177P00230000000
# owner_raw_name:LAROSA EMILY C
# db: LAROSA EMILY C **** county: LAROSA EMILY C
# True
#
#
# {'street': 'PATTERSON AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170084, '0235B00311000000', 'PATTERSON AVE', 'PITTSBURGH', 'PA', '15218')
# 'PATTERSON AVE'
# [('PUSATERI MARY E', 80084)]
# {'lname': 'PUSATERI MARY E', 'personid': 80084}
# [(80084,)]
# waiting:0.7459648588096301
# Scraping data from county: %s0235B00311000000
# owner_raw_name:PUSATERI MARY E
# db: PUSATERI MARY E **** county: PUSATERI MARY E
# True
#
#
# {'street': '1414 POCONO ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170085, '0178J00040000000', '1414 POCONO ST', 'PITTSBURGH', 'PA', '15218')
# '1414 POCONO ST'
# [('ENGSTROM MAUREEN M', 80085)]
# {'lname': 'ENGSTROM MAUREEN M', 'personid': 80085}
# [(80085,)]
# waiting:0.7037535758780251
# Scraping data from county: %s0178J00040000000
# owner_raw_name:ENGSTROM MAUREEN M
# db: ENGSTROM MAUREEN M **** county: ENGSTROM MAUREEN M
# True
#
#
# {'street': '7454 SCHOYER AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170086, '0177R00192000000', '7454 SCHOYER AVE', 'PITTSBURGH', 'PA', '15218')
# '7454 SCHOYER AVE'
# [('ALFONSO- PILLOT VLADIMIR & SHAWN ALFONSO-WELLS (W)', 80086)]
# {'lname': 'ALFONSO- PILLOT VLADIMIR & SHAWN ALFONSO-WELLS (W)', 'personid': 80086}
# [(80086,)]
# waiting:0.2934242093742835
# Scraping data from county: %s0177R00192000000
# owner_raw_name:ALFONSO- PILLOT VLADIMIR &  SHAWN   ALFONSO-WELLS (W)
# db: ALFONSO- PILLOT VLADIMIR & SHAWN ALFONSO-WELLS (W) **** county: ALFONSO- PILLOT VLADIMIR & SHAWN ALFONSO-WELLS (W)
# True
#
#
# {'street': 'RAYMOND ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170087, '0177N00120000000', 'RAYMOND ST', 'PITTSBURGH', 'PA', '15218')
# 'RAYMOND ST'
# [('CITY OF PITTSBURGH', 80087)]
# {'lname': 'CITY OF PITTSBURGH', 'personid': 80087}
# [(80087,)]
# waiting:0.12062650384149243
# Scraping data from county: %s0177N00120000000
# owner_raw_name:CITY OF PITTSBURGH
# db: CITY OF PITTSBURGH **** county: CITY OF PITTSBURGH
# True
#
#
# {'street': '2250 LEHIGH ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170088, '0234K00102000000', '2250 LEHIGH ST', 'PITTSBURGH', 'PA', '15218')
# '2250 LEHIGH ST'
# [('SCULLION BRIAN SPIES SHANNON (W)', 80088)]
# {'lname': 'SCULLION BRIAN SPIES SHANNON (W)', 'personid': 80088}
# [(80088,)]
# waiting:0.3533459098349374
# Scraping data from county: %s0234K00102000000
# owner_raw_name:SCULLION BRIAN     SPIES SHANNON (W)
# db: SCULLION BRIAN SPIES SHANNON (W) **** county: SCULLION BRIAN SPIES SHANNON (W)
# True
#
#
# {'street': '7520 CENTER ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170089, '0178H00091000000', '7520 CENTER ST', 'PITTSBURGH', 'PA', '15218')
# '7520 CENTER ST'
# [('MOBIT ISAIAH A', 80089)]
# {'lname': 'MOBIT ISAIAH A', 'personid': 80089}
# [(80089,)]
# waiting:0.5382223280419522
# Scraping data from county: %s0178H00091000000
# owner_raw_name:MOBIT ISAIAH A
# db: MOBIT ISAIAH A **** county: MOBIT ISAIAH A
# True
#
#
# {'street': '2532 S BRADDOCK AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170090, '0235P00338000000', '2532 S BRADDOCK AVE', 'PITTSBURGH', 'PA', '15218')
# '2532 S BRADDOCK AVE'
# [('RUDGE WILLIAM A JR & JANET (W)', 80090)]
# {'lname': 'RUDGE WILLIAM A JR & JANET (W)', 'personid': 80090}
# [(80090,)]
# waiting:0.7709673320505984
# Scraping data from county: %s0235P00338000000
# owner_raw_name:RUDGE WILLIAM A JR &  JANET (W)
# db: RUDGE WILLIAM A JR & JANET (W) **** county: RUDGE WILLIAM A JR & JANET (W)
# True
#
#
# {'street': '7105 CHURCH ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170091, '0178F00325000000', '7105 CHURCH ST', 'PITTSBURGH', 'PA', '15218')
# '7105 CHURCH ST'
# [('FORCUCCI ANTHONY V & JODY L CHECCHIO', 80091)]
# {'lname': 'FORCUCCI ANTHONY V & JODY L CHECCHIO', 'personid': 80091}
# [(80091,)]
# waiting:0.10497553658850822
# Scraping data from county: %s0178F00325000000
# owner_raw_name:FORCUCCI ANTHONY V &  JODY L CHECCHIO
# db: FORCUCCI ANTHONY V & JODY L CHECCHIO **** county: FORCUCCI ANTHONY V & JODY L CHECCHIO
# True
#
#
# {'street': '2332 BUENA VISTA ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170092, '0235E00290000000', '2332 BUENA VISTA ST', 'PITTSBURGH', 'PA', '15218')
# '2332 BUENA VISTA ST'
# [('MAARE VENTURES LLC', 80092)]
# {'lname': 'MAARE VENTURES LLC', 'personid': 80092}
# [(80092,)]
# waiting:0.18206979793271194
# Scraping data from county: %s0235E00290000000
# owner_raw_name:MAARE VENTURES LLC
# db: MAARE VENTURES LLC **** county: MAARE VENTURES LLC
# True
#
#
# {'street': '1625 NEVADA ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170093, '0178A00145000300', '1625 NEVADA ST', 'PITTSBURGH', 'PA', '15218')
# '1625 NEVADA ST'
# [('HOLLINGER BRIAN J & KRISTEN (W)', 80093)]
# {'lname': 'HOLLINGER BRIAN J & KRISTEN (W)', 'personid': 80093}
# [(80093,)]
# waiting:0.25023751798847826
# Scraping data from county: %s0178A00145000300
# owner_raw_name:HOLLINGER BRIAN J &  KRISTEN (W)
# db: HOLLINGER BRIAN J & KRISTEN (W) **** county: HOLLINGER BRIAN J & KRISTEN (W)
# True
#
#
# {'street': 'ARTHUR ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170094, '0178L00363000000', 'ARTHUR ST', 'PITTSBURGH', 'PA', '15218')
# 'ARTHUR ST'
# [('KENNY BRIDGET T', 80094)]
# {'lname': 'KENNY BRIDGET T', 'personid': 80094}
# [(80094,)]
# waiting:0.8319632863859866
# Scraping data from county: %s0178L00363000000
# owner_raw_name:KENNY BRIDGET T
# db: KENNY BRIDGET T **** county: KENNY BRIDGET T
# True
#
#
# {'street': '2223 MANOR AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (170095, '0235E00167000000', '2223 MANOR AVE', 'PITTSBURGH', 'PA', '15218')
# '2223 MANOR AVE'
# [('GLANCE THOMAS H', 80095)]
# {'lname': 'GLANCE THOMAS H', 'personid': 80095}
# [(80095,)]
# waiting:0.33151847388459577
# Scraping data from county: %s0235E00167000000
# owner_raw_name:GLANCE THOMAS H
# db: GLANCE THOMAS H **** county: GLANCE THOMAS H
# True
#
#
# ...
# (172261, '0178D00011000A00', '7701 CANNON ST', 'PITTSBURGH', 'PA', '15218')
# '7701 CANNON ST'
# [('COSTELLO DONALD & ROBERTA (W)', 82256)]
# {'lname': 'COSTELLO DONALD & ROBERTA (W)', 'personid': 82256}
# [(82256,)]
# waiting:0.06433615499654499
# Scraping data from county: %s0178D00011000A00
# owner_raw_name:COSTELLO DONALD &  ROBERTA (W)
# db: COSTELLO DONALD & ROBERTA (W) **** county: COSTELLO DONALD & ROBERTA (W)
# True
#
#
# {'street': '7330 -7336 WOODLAWN AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172262, '0178F00215000000', '7330 -7336 WOODLAWN AVE', 'PITTSBURGH', 'PA', '15218')
# '7330 -7336 WOODLAWN AVE'
# [('EGSN PROPERTIES LLC', 82257)]
# {'lname': 'EGSN PROPERTIES LLC', 'personid': 82257}
# [(82257,)]
# waiting:0.25985255752640535
# Scraping data from county: %s0178F00215000000
# owner_raw_name:EGSN PROPERTIES LLC
# db: EGSN PROPERTIES LLC **** county: EGSN PROPERTIES LLC
# True
#
#
# {'street': '2224 LACROSSE ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172263, '0234N00066000000', '2224 LACROSSE ST', 'PITTSBURGH', 'PA', '15218')
# '2224 LACROSSE ST'
# [('BALKOVEC JOSEPH EDWARD JR & STELLA PATRI CIA (W)', 82258)]
# {'lname': 'BALKOVEC JOSEPH EDWARD JR & STELLA PATRI CIA (W)', 'personid': 82258}
# [(82258,)]
# waiting:0.04571479758870556
# Scraping data from county: %s0234N00066000000
# owner_raw_name:BALKOVEC JOSEPH EDWARD JR &  STELLA PATRI   CIA (W)
# db: BALKOVEC JOSEPH EDWARD JR & STELLA PATRI CIA (W) **** county: BALKOVEC JOSEPH EDWARD JR & STELLA PATRI CIA (W)
# True
#
#
# {'street': 'HIGHLAND AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172264, '0235F00023000000', 'HIGHLAND AVE', 'PITTSBURGH', 'PA', '15218')
# 'HIGHLAND AVE'
# [('PELLIS J W', 82259)]
# {'lname': 'PELLIS J W', 'personid': 82259}
# [(82259,)]
# waiting:0.22336353372530204
# Scraping data from county: %s0235F00023000000
# owner_raw_name:PELLIS J W
# db: PELLIS J W **** county: PELLIS J W
# True
#
#
# {'street': '109 LILMONT DR', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172265, '0235R00188000000', '109 LILMONT DR', 'PITTSBURGH', 'PA', '15218')
# '109 LILMONT DR'
# [('LILMONT PROPERTIES LLC', 82260)]
# {'lname': 'LILMONT PROPERTIES LLC', 'personid': 82260}
# [(82260,)]
# waiting:0.43554414288975896
# Scraping data from county: %s0235R00188000000
# owner_raw_name:LILMONT PROPERTIES LLC
# db: LILMONT PROPERTIES LLC **** county: LILMONT PROPERTIES LLC
# True
#
#
# {'street': '7467 MCCLURE AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172266, '0177R00224000000', '7467 MCCLURE AVE', 'PITTSBURGH', 'PA', '15218')
# '7467 MCCLURE AVE'
# [('REMALEY CHRISTOPHER A', 82261)]
# {'lname': 'REMALEY CHRISTOPHER A', 'personid': 82261}
# [(82261,)]
# waiting:0.5602387815265427
# Scraping data from county: %s0177R00224000000
# owner_raw_name:REMALEY CHRISTOPHER A
# db: REMALEY CHRISTOPHER A **** county: REMALEY CHRISTOPHER A
# True
#
#
# {'street': 'DELAWARE AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172267, '0235B00098000000', 'DELAWARE AVE', 'PITTSBURGH', 'PA', '15218')
# 'DELAWARE AVE'
# [('SOUTHPAW PROPERTY LLC', 82262)]
# {'lname': 'SOUTHPAW PROPERTY LLC', 'personid': 82262}
# [(82262,)]
# waiting:0.9786458730693236
# Scraping data from county: %s0235B00098000000
# owner_raw_name:SOUTHPAW PROPERTY LLC
# db: SOUTHPAW PROPERTY LLC **** county: SOUTHPAW PROPERTY LLC
# True
#
#
# {'street': '7007 MCCLURE AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172268, '0178E00016000000', '7007 MCCLURE AVE', 'PITTSBURGH', 'PA', '15218')
# '7007 MCCLURE AVE'
# [('PASCAL SAM', 82263)]
# {'lname': 'PASCAL SAM', 'personid': 82263}
# [(82263,)]
# waiting:0.025999374624077864
# Scraping data from county: %s0178E00016000000
# owner_raw_name:PASCAL SAM
# db: PASCAL SAM **** county: PASCAL SAM
# True
#
#
# {'street': '7330 SCHLEY AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172269, '0178L00222000000', '7330 SCHLEY AVE', 'PITTSBURGH', 'PA', '15218')
# '7330 SCHLEY AVE'
# [('BENSASI SALEM & MARY JO (W)', 82264)]
# {'lname': 'BENSASI SALEM & MARY JO (W)', 'personid': 82264}
# [(82264,)]
# waiting:0.6576817521295782
# Scraping data from county: %s0178L00222000000
# owner_raw_name:BENSASI SALEM  &  MARY JO (W)
# db: BENSASI SALEM & MARY JO (W) **** county: BENSASI SALEM & MARY JO (W)
# True
#
#
# {'street': '7133 HARRISON AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172270, '0178A00213000000', '7133 HARRISON AVE', 'PITTSBURGH', 'PA', '15218')
# '7133 HARRISON AVE'
# [('COHEN TIMOTHY L', 82265)]
# {'lname': 'COHEN TIMOTHY L', 'personid': 82265}
# [(82265,)]
# waiting:0.03963929342965122
# Scraping data from county: %s0178A00213000000
# owner_raw_name:COHEN TIMOTHY L
# db: COHEN TIMOTHY L **** county: COHEN TIMOTHY L
# True
#
#
# {'street': '7436 WASHINGTON AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172271, '0178G00260000000', '7436 WASHINGTON AVE', 'PITTSBURGH', 'PA', '15218')
# '7436 WASHINGTON AVE'
# [('ZITELLI JOHN F', 82266)]
# {'lname': 'ZITELLI JOHN F', 'personid': 82266}
# [(82266,)]
# waiting:0.13970802786320435
# Scraping data from county: %s0178G00260000000
# owner_raw_name:ZITELLI JOHN F
# db: ZITELLI JOHN F **** county: ZITELLI JOHN F
# True
#
#
# {'street': '8104 SAINT LAWRENCE AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172272, '0234J00052000000', '8104 SAINT LAWRENCE AVE', 'PITTSBURGH', 'PA', '15218')
# '8104 SAINT LAWRENCE AVE'
# [('LOVELAND STEPHANIE STORM', 82267)]
# {'lname': 'LOVELAND STEPHANIE STORM', 'personid': 82267}
# [(82267,)]
# waiting:0.0033265839434096778
# Scraping data from county: %s0234J00052000000
# owner_raw_name:LOVELAND STEPHANIE STORM
# db: LOVELAND STEPHANIE STORM **** county: LOVELAND STEPHANIE STORM
# True
#
#
# {'street': '2223 COLUMBIA AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172273, '0235A00020000000', '2223 COLUMBIA AVE', 'PITTSBURGH', 'PA', '15218')
# '2223 COLUMBIA AVE'
# [('WALKER MARILYN J', 82268)]
# {'lname': 'WALKER MARILYN J', 'personid': 82268}
# [(82268,)]
# waiting:0.1523710193869825
# Scraping data from county: %s0235A00020000000
# owner_raw_name:WALKER MARILYN J
# db: WALKER MARILYN J **** county: WALKER MARILYN J
# True
#
#
# {'street': '2227 DELAWARE AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172274, '0234N00129000000', '2227 DELAWARE AVE', 'PITTSBURGH', 'PA', '15218')
# '2227 DELAWARE AVE'
# [('SANDS PATRICK DONALD BARBERA KATHERINE MICHELLE', 82269)]
# {'lname': 'SANDS PATRICK DONALD BARBERA KATHERINE MICHELLE', 'personid': 82269}
# [(82269,)]
# waiting:0.4622161357538769
# Scraping data from county: %s0234N00129000000
# owner_raw_name:SANDS PATRICK DONALD     BARBERA KATHERINE MICHELLE
# db: SANDS PATRICK DONALD BARBERA KATHERINE MICHELLE **** county: SANDS PATRICK DONALD BARBERA KATHERINE MICHELLE
# True
#
#
# {'street': 'WOODSTOCK AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172275, '0235P00301000000', 'WOODSTOCK AVE', 'PITTSBURGH', 'PA', '15218')
# 'WOODSTOCK AVE'
# [('JACKSON JOHN & MARIA', 82270)]
# {'lname': 'JACKSON JOHN & MARIA', 'personid': 82270}
# [(82270,)]
# waiting:0.5026357872446835
# Scraping data from county: %s0235P00301000000
# owner_raw_name:JACKSON JOHN  &  MARIA
# db: JACKSON JOHN & MARIA **** county: JACKSON JOHN & MARIA
# True
#
#
# {'street': '7480 MCCLURE AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172276, '0177R00273000000', '7480 MCCLURE AVE', 'PITTSBURGH', 'PA', '15218')
# '7480 MCCLURE AVE'
# [('POKOL CLIFFORD A', 82271)]
# {'lname': 'POKOL CLIFFORD A', 'personid': 82271}
# [(82271,)]
# waiting:0.6714728044154187
# Scraping data from county: %s0177R00273000000
# owner_raw_name:POKOL CLIFFORD A
# db: POKOL CLIFFORD A **** county: POKOL CLIFFORD A
# True
#
#
# {'street': 'PATTERSON AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172277, '0235B00297000000', 'PATTERSON AVE', 'PITTSBURGH', 'PA', '15218')
# 'PATTERSON AVE'
# [('SPUDICH JASON N', 82272)]
# {'lname': 'SPUDICH JASON N', 'personid': 82272}
# [(82272,)]
# waiting:0.38162158791147804
# Scraping data from county: %s0235B00297000000
# owner_raw_name:SPUDICH JASON N
# db: SPUDICH JASON N **** county: SPUDICH JASON N
# True
#
#
# {'street': '7912 EDGEWOOD AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172278, '0177S00096000000', '7912 EDGEWOOD AVE', 'PITTSBURGH', 'PA', '15218')
# '7912 EDGEWOOD AVE'
# [('NESTOR MADISON M SHARICK JACOB', 82273)]
# {'lname': 'NESTOR MADISON M SHARICK JACOB', 'personid': 82273}
# [(82273,)]
# waiting:0.7644644261589366
# Scraping data from county: %s0177S00096000000
# owner_raw_name:NESTOR MADISON M     SHARICK JACOB
# db: NESTOR MADISON M SHARICK JACOB **** county: NESTOR MADISON M SHARICK JACOB
# True
#
#
# {'street': '7212 WHIPPLE ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172279, '0177N00261000000', '7212 WHIPPLE ST', 'PITTSBURGH', 'PA', '15218')
# '7212 WHIPPLE ST'
# [('RIZZO CARMELA HONE ERIC', 82274)]
# {'lname': 'RIZZO CARMELA HONE ERIC', 'personid': 82274}
# [(82274,)]
# waiting:0.8935744103243812
# Scraping data from county: %s0177N00261000000
# owner_raw_name:RIZZO CARMELA     HONE ERIC
# db: RIZZO CARMELA HONE ERIC **** county: RIZZO CARMELA HONE ERIC
# True
#
#
# {'street': 'S BRADDOCK AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172280, '0235P00214000000', 'S BRADDOCK AVE', 'PITTSBURGH', 'PA', '15218')
# 'S BRADDOCK AVE'
# [('PORT AUTHORITY OF ALLEGHENY COUNTY', 82275)]
# {'lname': 'PORT AUTHORITY OF ALLEGHENY COUNTY', 'personid': 82275}
# [(82275,)]
# waiting:0.8922429010438951
# Scraping data from county: %s0235P00214000000
# owner_raw_name:PORT AUTHORITY OF ALLEGHENY COUNTY
# db: PORT AUTHORITY OF ALLEGHENY COUNTY **** county: PORT AUTHORITY OF ALLEGHENY COUNTY
# True
#
#
# {'street': 'BRUCE WAY', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172281, '0235P00325000000', 'BRUCE WAY', 'PITTSBURGH', 'PA', '15218')
# 'BRUCE WAY'
# [('COUNTY OF ALLEGHENY BOROUGH OF SWISSVALESCHOOL DISTRICT OF BORO OF SWISSVALE', 82276)]
# {'lname': 'COUNTY OF ALLEGHENY BOROUGH OF SWISSVALESCHOOL DISTRICT OF BORO OF SWISSVALE', 'personid': 82276}
# [(82276,)]
# waiting:0.03222748063157532
# Scraping data from county: %s0235P00325000000
# owner_raw_name:COUNTY OF ALLEGHENY     BOROUGH OF SWISSVALESCHOOL DISTRICT OF BORO OF SWISSVALE
# db: COUNTY OF ALLEGHENY BOROUGH OF SWISSVALESCHOOL DISTRICT OF BORO OF SWISSVALE **** county: COUNTY OF ALLEGHENY BOROUGH OF SWISSVALESCHOOL DISTRICT OF BORO OF SWISSVALE
# True
#
#
# {'street': '2331 MANOR AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172282, '0235E00127000000', '2331 MANOR AVE', 'PITTSBURGH', 'PA', '15218')
# '2331 MANOR AVE'
# [('JUMBA STEPHEN E JR & SHARON ANN MURAJDA (W)', 82277)]
# {'lname': 'JUMBA STEPHEN E JR & SHARON ANN MURAJDA (W)', 'personid': 82277}
# [(82277,)]
# waiting:0.042812189953850055
# Scraping data from county: %s0235E00127000000
# owner_raw_name:JUMBA STEPHEN E JR &  SHARON ANN MURAJDA    (W)
# db: JUMBA STEPHEN E JR & SHARON ANN MURAJDA (W) **** county: JUMBA STEPHEN E JR & SHARON ANN MURAJDA (W)
# True
#
#
# {'street': 'R OF W', 'city': 'HOMESTEAD', 'state': 'PA', 'zip': '15120'}
# (172283, '0130H00200000900', 'R OF W', 'HOMESTEAD', 'PA', '15120')
# 'R OF W'
# [('CSX TRANSPORTATION INC', 82278)]
# {'lname': 'CSX TRANSPORTATION INC', 'personid': 82278}
# [(82278,)]
# waiting:0.11043311997366034
# Scraping data from county: %s0130H00200000900
# owner_raw_name:CSX TRANSPORTATION INC
# db: CSX TRANSPORTATION INC **** county: CSX TRANSPORTATION INC
# True
#
#
# {'street': 'STANTON AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172284, '0178D00104000100', 'STANTON AVE', 'PITTSBURGH', 'PA', '15218')
# 'STANTON AVE'
# [('KITCHENS EVELYN H', 82279)]
# {'lname': 'KITCHENS EVELYN H', 'personid': 82279}
# [(82279,)]
# waiting:0.3093883791167885
# Scraping data from county: %s0178D00104000100
# owner_raw_name:KITCHENS EVELYN H
# db: KITCHENS EVELYN H **** county: KITCHENS EVELYN H
# True
#
#
# {'street': '1442 LACLAIR ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172285, '0177K00068000000', '1442 LACLAIR ST', 'PITTSBURGH', 'PA', '15218')
# '1442 LACLAIR ST'
# [('BUCHANAN RONALD BLAIR & DIANE SCHEUERMAN N (W)', 82280)]
# {'lname': 'BUCHANAN RONALD BLAIR & DIANE SCHEUERMAN N (W)', 'personid': 82280}
# [(82280,)]
# waiting:0.8072367539750603
# Scraping data from county: %s0177K00068000000
# owner_raw_name:BUCHANAN RONALD BLAIR &  DIANE SCHEUERMAN   N (W)
# db: BUCHANAN RONALD BLAIR & DIANE SCHEUERMAN N (W) **** county: BUCHANAN RONALD BLAIR & DIANE SCHEUERMAN N (W)
# True
#
#
# {'street': '2213 HAWTHORNE AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172286, '0235A00283000000', '2213 HAWTHORNE AVE', 'PITTSBURGH', 'PA', '15218')
# '2213 HAWTHORNE AVE'
# [('BOYLES AMY LYNN & DAVID (H)', 82281)]
# {'lname': 'BOYLES AMY LYNN & DAVID (H)', 'personid': 82281}
# [(82281,)]
# waiting:0.43989066406061783
# Scraping data from county: %s0235A00283000000
# owner_raw_name:BOYLES AMY LYNN &  DAVID (H)
# db: BOYLES AMY LYNN & DAVID (H) **** county: BOYLES AMY LYNN & DAVID (H)
# True
#
#
# {'street': '2038 MONROE ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172287, '0178G00081000000', '2038 MONROE ST', 'PITTSBURGH', 'PA', '15218')
# '2038 MONROE ST'
# [('PALANGIO VERA', 82282)]
# {'lname': 'PALANGIO VERA', 'personid': 82282}
# [(82282,)]
# waiting:0.8490890269948446
# Scraping data from county: %s0178G00081000000
# owner_raw_name:PALANGIO VERA
# db: PALANGIO VERA **** county: PALANGIO VERA
# True
#
#
# {'street': '2025 MONROE ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172288, '0178G00063000000', '2025 MONROE ST', 'PITTSBURGH', 'PA', '15218')
# '2025 MONROE ST'
# [('HELLER GRETCHEN', 82283)]
# {'lname': 'HELLER GRETCHEN', 'personid': 82283}
# [(82283,)]
# waiting:0.8211554319214978
# Scraping data from county: %s0178G00063000000
# owner_raw_name:HELLER GRETCHEN
# db: HELLER GRETCHEN **** county: HELLER GRETCHEN
# True
#
#
# {'street': '1421 MACON AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172289, '0177K00046000000', '1421 MACON AVE', 'PITTSBURGH', 'PA', '15218')
# '1421 MACON AVE'
# [('SCHROTH RYAN LIND AMY', 82284)]
# {'lname': 'SCHROTH RYAN LIND AMY', 'personid': 82284}
# [(82284,)]
# waiting:0.4715943541537623
# Scraping data from county: %s0177K00046000000
# owner_raw_name:SCHROTH RYAN     LIND AMY
# db: SCHROTH RYAN LIND AMY **** county: SCHROTH RYAN LIND AMY
# True
#
#
# {'street': '2216 HAMPTON ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172290, '0234N00094000000', '2216 HAMPTON ST', 'PITTSBURGH', 'PA', '15218')
# '2216 HAMPTON ST'
# [('MYERS MICAH Y & SARA P (W)', 82285)]
# {'lname': 'MYERS MICAH Y & SARA P (W)', 'personid': 82285}
# [(82285,)]
# waiting:0.48021934329397353
# Scraping data from county: %s0234N00094000000
# owner_raw_name:MYERS MICAH Y &  SARA P (W)
# db: MYERS MICAH Y & SARA P (W) **** county: MYERS MICAH Y & SARA P (W)
# True
#
#
# {'street': '7517 ARDMORE ST', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172291, '0178M00124000000', '7517 ARDMORE ST', 'PITTSBURGH', 'PA', '15218')
# '7517 ARDMORE ST'
# [('CAROZZA MARIE L WHETSEL BEATRICE AVAN BALEN V THOMASDUNMIRE BARBARA V B', 82286)]
# {'lname': 'CAROZZA MARIE L WHETSEL BEATRICE AVAN BALEN V THOMASDUNMIRE BARBARA V B', 'personid': 82286}
# [(82286,)]
# waiting:0.9617528180812419
# Scraping data from county: %s0178M00124000000
# owner_raw_name:CAROZZA MARIE L     WHETSEL BEATRICE AVAN BALEN V THOMASDUNMIRE BARBARA V B
# db: CAROZZA MARIE L WHETSEL BEATRICE AVAN BALEN V THOMASDUNMIRE BARBARA V B **** county: CAROZZA MARIE L WHETSEL BEATRICE AVAN BALEN V THOMASDUNMIRE BARBARA V B
# True
#
#
# {'street': '7925 LLOYD AVE', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172292, '0234P00009000000', '7925 LLOYD AVE', 'PITTSBURGH', 'PA', '15218')
# '7925 LLOYD AVE'
# [('HUBER CATHERINE S HUBER CHRISTOPHER', 82287)]
# {'lname': 'HUBER CATHERINE S HUBER CHRISTOPHER', 'personid': 82287}
# [(82287,)]
# waiting:0.3621394009019894
# Scraping data from county: %s0234P00009000000
# owner_raw_name:HUBER CATHERINE S     HUBER CHRISTOPHER
# db: HUBER CATHERINE S HUBER CHRISTOPHER **** county: HUBER CATHERINE S HUBER CHRISTOPHER
# True
#
#
# {'street': '207 LILMONT DR', 'city': 'PITTSBURGH', 'state': 'PA', 'zip': '15218'}
# (172293, '0235R00172000000', '207 LILMONT DR', 'PITTSBURGH', 'PA', '15218')
# '207 LILMONT DR'
# [('LE BAITE LLC', 82288)]
# {'lname': 'LE BAITE LLC', 'personid': 82288}
# [(82288,)]
# waiting:0.9158631530265573
